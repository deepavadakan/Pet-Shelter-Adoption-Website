# %% [markdown]
# ## Import Dependencies

# %%
import petpy
from petpy import Petfinder
from config import API_key, API_secret
import json
import pymongo
import pandas as pd
from pprint import pprint

# %% [markdown]
# ## API Call and Pandas DF Processing

# %%
pf = Petfinder(key=API_key, secret=API_secret)

# %%
# Use petfinder API with animals endpoint, w/ specific limits to get most possible results; 
# return as a pandas df
animal_df = pf.animals(results_per_page=100, pages=100, return_df=True)
# Out:
# C:\Users\kaldm\anaconda3\envs\PythonData\lib\site-packages\petpy\api.py:1049: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   results_df = json_normalize(results[key])

# %%
# make dataframe copy to preserve API call results
animal2_df = animal_df.copy()

# %%
# get rid of extra organization_id column caugin an error 
my_columns = list(range(0,48))
animal2_df = animal2_df.iloc[:,my_columns]

# %%
# inspect list for column name formats
column_list = list(animal2_df.columns) 
column_list
# Out:
# ['id',
#  'organization_id',
#  'url',
#  'type',
#  'species',
#  'age',
#  'gender',
#  'size',
#  'coat',
#  'tags',
#  'name',
#  'description',
#  'organization_animal_id',
#  'photos',
#  'videos',
#  'status',
#  'status_changed_at',
#  'published_at',
#  'distance',
#  'breeds.primary',
#  'breeds.secondary',
#  'breeds.mixed',
#  'breeds.unknown',
#  'colors.primary',
#  'colors.secondary',
#  'colors.tertiary',
#  'attributes.spayed_neutered',
#  'attributes.house_trained',
#  'attributes.declawed',
#  'attributes.special_needs',
#  'attributes.shots_current',
#  'environment.children',
#  'environment.dogs',
#  'environment.cats',
#  'primary_photo_cropped.small',
#  'primary_photo_cropped.medium',
#  'primary_photo_cropped.large',
#  'primary_photo_cropped.full',
#  'contact.email',
#  'contact.phone',
#  'contact.address.address1',
#  'contact.address.address2',
#  'contact.address.city',
#  'contact.address.state',
#  'contact.address.postcode',
#  'contact.address.country',
#  'animal_id',
#  'animal_type']

# %%
# change column header names in animal2_df to remove dot notation for mongo
animal3_df = animal2_df.rename(columns = {
 'breeds.primary':'breeds_primary',
 'breeds.secondary': 'breeds_secondary',
 'breeds.mixed': 'breeds_mixed',
 'breeds.unknown':'breeds_unknown',
 'colors.primary': 'colors_primary',
 'colors.secondary': 'colors_secondary',
 'colors.tertiary': 'colors_tertiary',
 'attributes.spayed_neutered': 'attributes_spayed_neutered',
 'attributes.house_trained': 'attributes_house_trained',
 'attributes.declawed': 'attributes_declawed',
 'attributes.special_needs': 'attributes_special_needs',
 'attributes.shots_current': 'attributes_shots_current',
 'environment.children': 'environment_children',
 'environment.dogs': 'environment_dogs',
 'environment.cats': 'environment_cats',
 'primary_photo_cropped.small': 'primary_photo_cropped_small',
 'primary_photo_cropped.medium': 'primary_photo_cropped_medium',
 'primary_photo_cropped.large': 'primary_photo_cropped_large',
 'primary_photo_cropped.full': 'primary_photo_cropped_full',
 'contact.email': 'contact_email',
 'contact.phone': 'contact_phone',
 'contact.address.address1': 'contact_address_address1',
 'contact.address.address2': 'contact_address_address2',
 'contact.address.city': 'contact_address_city',
 'contact.address.state': 'contact_address_state',
 'contact.address.postcode': 'contact_address_postcode',
 'contact.address.country': 'contact_address_country'})

# %%
animal3_df.head()
# Out:
#          id organization_id  \
# 0  50398452            IN64
# 1  50398488            WI47
# 2  50398489            WI47
# 3  50398490            WI47
# 4  50398491            WI47
#
#                                                  url type species    age  \
# 0  https://www.petfinder.com/cat/gidget-50398452/...  Cat     Cat  Adult
# 1  https://www.petfinder.com/dog/lesa-50398488/wi...  Dog     Dog  Adult
# 2  https://www.petfinder.com/cat/sky-50398489/wi/...  Cat     Cat  Young
# 3  https://www.petfinder.com/dog/kimber-50398490/...  Dog     Dog  Adult
# 4  https://www.petfinder.com/cat/timmy-50398491/w...  Cat     Cat   Baby
#
#    gender    size   coat tags  ...                       contact_email  \
# 0  Female  Medium  Short   []  ...  animalcareservices@columbus.in.gov
# 1  Female   Large   None   []  ...                 elmbrookhs@ebhs.org
# 2  Female  Medium   None   []  ...                 elmbrookhs@ebhs.org
# 3    Male  Medium   None   []  ...                 elmbrookhs@ebhs.org
# 4  Female   Small   None   []  ...                 elmbrookhs@ebhs.org
#
#       contact_phone contact_address_address1 contact_address_address2  \
# 0  812-376-2505               2730 Arnold St                     None
# 1    (262) 782-9261  20950 Enterprise Avenue                     None
# 2    (262) 782-9261  20950 Enterprise Avenue                     None
# 3    (262) 782-9261  20950 Enterprise Avenue                     None
# 4    (262) 782-9261  20950 Enterprise Avenue                     None
#
#   contact_address_city contact_address_state contact_address_postcode  \
# 0             Columbus                    IN                    47203
# 1           Brookfield                    WI                    53045
# 2           Brookfield                    WI                    53045
# 3           Brookfield                    WI                    53045
# 4           Brookfield                    WI                    53045
#
#   contact_address_country animal_id animal_type
# 0                      US  50398452         cat
# 1                      US  50398488         dog
# 2                      US  50398489         cat
# 3                      US  50398490         dog
# 4                      US  50398491         cat
#
# [5 rows x 48 columns]

# %%
organizations_df = pf.organizations(results_per_page=100, pages=100, return_df=True)
# Out:
# C:\Users\kaldm\anaconda3\envs\PythonData\lib\site-packages\petpy\api.py:1049: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   results_df = json_normalize(results[key])

# %%
# photos field is creating an error in pandas because it contains a list within the field. 
org_df = organizations_df.drop(columns=['photos'])

# %%
# change column header names to remove dot notation for mongo
org2_df = org_df.rename(columns = {
 'address.address1': "address_address1",
 'address.address2': "address_address2",
 'address.city': "address_city" ,
 'address.state': "address_state",
 'address.postcode': "address_postcode",
 'address.country': "address_country",
 'hours.monday': "hours_monday",
 'hours.tuesday': "hours_tuesday",
 'hours.wednesday': "hours_wednesday",
 'hours.thursday': "hours_thursday",
 'hours.friday': "hours_friday",
 'hours.saturday': "hours_saturday",
 'hours.sunday': "hours_sunday",
 'adoption.policy': "adoption_policy" ,
 'adoption.url': "adoption_url",
 'social_media.facebook': "socialmedia_facebook",
 'social_media.twitter': "socialmedia_twitter",
 'social_media.youtube': "socialmedia_youtube",
 'social_media.instagram': "socialmedia_instagram",
 'social_media.pinterest': "socialmedia_pinterest",
})

# %%
# now try to drop duplicates - based on all columns
org2_df.drop_duplicates()
# new length is 8932
# Out:
#           id                                               name  \
# 0      PA912                         The Shelter Animal Project
# 1      GA762                        Special Touch Animal Rescue
# 2      OH749                     Purr-fect Companions Sanctuary
# 3      TX876                Gina's Heart of Gold Reptile Rescue
# 4      MO556  Montgomery City Animal Shelter/Project Preciou...
# ...      ...                                                ...
# 9995   FL271            Schnauzer and Fox Terrier Rescue League
# 9996   WA353                   Kitsap Animal Rescue & Education
# 9997   IA220                         Tama County Humane Society
# 9998  CA2267                                 Almost Eden Rescue
# 9999  CA2781  Community Canines (and The Great Dane Rescue o...
#
#                                   email           phone  \
# 0                tsapadoption@gmail.com            None
# 1                    STARRadopt@aol.com  (404) 983-3581
# 2            purrfectcompanions@att.net    216-671-6369
# 3               gdisteldorf@comcast.net  (713) 329-9304
# 4       projectpreciouspaws@hotmail.com  1-573-310-4979
# ...                                 ...             ...
# 9995               rescue2468@yahoo.com    407-333-0524
# 9996               adoptions@nwkare.org  (360) 602-6717
# 9997  tamacountyhumanesociety@yahoo.com  (641) 481-7001
# 9998         almostedenrescue@yahoo.com            None
# 9999              info@communityk9s.org  (833) 266-6597
#
#                                                     url  \
# 0     https://www.petfinder.com/member/us/pa/fairles...
# 1     https://www.petfinder.com/member/us/ga/acworth...
# 2     https://www.petfinder.com/member/us/oh/lakewoo...
# 3     https://www.petfinder.com/member/us/tx/houston...
# 4     https://www.petfinder.com/member/us/mo/montgom...
# ...                                                 ...
# 9995  https://www.petfinder.com/member/us/fl/altamon...
# 9996  https://www.petfinder.com/member/us/wa/silverd...
# 9997  https://www.petfinder.com/member/us/ia/tama/ta...
# 9998  https://www.petfinder.com/member/us/ca/ridgecr...
# 9999  https://www.petfinder.com/member/us/ca/murriet...
#
#                                                 website  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                                https://nwkare.org/
# 9997  https://www.facebook.com/TamaCountyHumaneSociety/
# 9998                        http://AlmostEdenRescue.com
# 9999                       https://www.communityk9s.org
#
#                                       mission_statement distance  \
# 0                                                  None     None
# 1     We are a private foster home group. We are NOT...     None
# 2                                                  None     None
# 3                                                  None     None
# 4                                                  None     None
# ...                                                 ...      ...
# 9995                                               None     None
# 9996  Check us out at www.nwkare.org! Where you can ...     None
# 9997  The Tama County Humane Society  is an organiza...     None
# 9998  We  are a foster-based rescue and operate with...     None
# 9999  Through education, training, rescue and kindne...     None
#
#        address_address1 address_address2  ... hours_saturday hours_sunday  \
# 0             PO Box 24             None  ...           None         None
# 1                  None             None  ...           None         None
# 2        P.O.Box 770992             None  ...           None         None
# 3                  None             None  ...           None         None
# 4     915 Benton Street             None  ...           None         None
# ...                 ...              ...  ...            ...          ...
# 9995               None             None  ...           None         None
# 9996               None             None  ...           None         None
# 9997  1406 E 5th Street             None  ...       7am-11am         None
# 9998               None             None  ...           None         None
# 9999               None             None  ...           None         None
#
#                                         adoption_policy  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996  As a rescue group that utilizes a foster care ...
# 9997  See an animal that you like? Give us a call or...
# 9998  To adopt a new family member, we will require ...
# 9999                                               None
#
#                                            adoption_url  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                https://forms.gle/8Gi4oUoP5EVMwfyB7
# 9997  https://docs.google.com/forms/d/e/1FAIpQLSdaBs...
# 9998                                               None
# 9999  https://www.communityk9s.org/yahoo_site_admin/...
#
#                                    socialmedia_facebook socialmedia_twitter  \
# 0                                                  None                None
# 1                                                  None                None
# 2                                                  None                None
# 3                                                  None                None
# 4                                                  None                None
# ...                                                 ...                 ...
# 9995                                               None                None
# 9996                   https://www.facebook.com/nwkare/                None
# 9997  https://www.facebook.com/Adoptable-at-Tama-Cou...                None
# 9998         https://www.facebook.com/AlmostEdenRescue/                None
# 9999  https://www.facebook.com/commk9s/?modal=admin_...                None
#
#                                     socialmedia_youtube  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998  https://www.youtube.com/channel/UCGYWgri15xr-t...
# 9999                                               None
#
#                    socialmedia_instagram socialmedia_pinterest organization_id
# 0                                   None                  None           pa912
# 1                                   None                  None           ga762
# 2                                   None                  None           oh749
# 3                                   None                  None           tx876
# 4                                   None                  None           mo556
# ...                                  ...                   ...             ...
# 9995                                None                  None           fl271
# 9996  https://www.instagram.com/kare_nw/                  None           wa353
# 9997                                None                  None           ia220
# 9998                                None                  None          ca2267
# 9999                                None                  None          ca2781
#
# [9166 rows x 29 columns]

# %% [markdown]
# ## Lat and Long DF and Add to Org Collection

# %%
zipfile_df = pd.read_csv("col_resources/zip_lat_lon.csv")

# %%
zipcode_df = zipfile_df[["Zip", "Latitude", "Longitude"]]

# %%
#need to convert datatypes in order to merge dataframes 
convert_zipdict = {'Zip': str}
zip_converted_df = zipcode_df.astype(convert_zipdict)

# %%
#need to convert datatypes in order to merge dataframes
convert_orgdict = {'address_postcode': str}
org_converted_df = org2_df.astype(convert_orgdict)

# %%
#rename field in zipcode to merge with org df 
new_zip_df = zip_converted_df.rename(columns={'Zip': 'address_postcode'})

# %%
#merge zip code and org dataframes - now every org should have a corresponding latlong
org_zip_df = pd.merge(new_zip_df, org_converted_df,  how= "inner", on=["address_postcode", "address_postcode"])

# %%
org_zip2_df = org_zip_df.drop(columns=['organization_id'])

# %%
# rename id column (with CAPS) as organization_id column
org_zip3_df = org_zip2_df.rename(columns={'id': 'organization_id'})

# %%
# convert datatypes in order to merge dataframes 
convert_animaldict = {'id': float}
animal_conv_df = animal3_df.astype(convert_animaldict)

# %%
animal_conv_df.head()
# Out:
#            id organization_id  \
# 0  50398452.0            IN64
# 1  50398488.0            WI47
# 2  50398489.0            WI47
# 3  50398490.0            WI47
# 4  50398491.0            WI47
#
#                                                  url type species    age  \
# 0  https://www.petfinder.com/cat/gidget-50398452/...  Cat     Cat  Adult
# 1  https://www.petfinder.com/dog/lesa-50398488/wi...  Dog     Dog  Adult
# 2  https://www.petfinder.com/cat/sky-50398489/wi/...  Cat     Cat  Young
# 3  https://www.petfinder.com/dog/kimber-50398490/...  Dog     Dog  Adult
# 4  https://www.petfinder.com/cat/timmy-50398491/w...  Cat     Cat   Baby
#
#    gender    size   coat tags  ...                       contact_email  \
# 0  Female  Medium  Short   []  ...  animalcareservices@columbus.in.gov
# 1  Female   Large   None   []  ...                 elmbrookhs@ebhs.org
# 2  Female  Medium   None   []  ...                 elmbrookhs@ebhs.org
# 3    Male  Medium   None   []  ...                 elmbrookhs@ebhs.org
# 4  Female   Small   None   []  ...                 elmbrookhs@ebhs.org
#
#       contact_phone contact_address_address1 contact_address_address2  \
# 0  812-376-2505               2730 Arnold St                     None
# 1    (262) 782-9261  20950 Enterprise Avenue                     None
# 2    (262) 782-9261  20950 Enterprise Avenue                     None
# 3    (262) 782-9261  20950 Enterprise Avenue                     None
# 4    (262) 782-9261  20950 Enterprise Avenue                     None
#
#   contact_address_city contact_address_state contact_address_postcode  \
# 0             Columbus                    IN                    47203
# 1           Brookfield                    WI                    53045
# 2           Brookfield                    WI                    53045
# 3           Brookfield                    WI                    53045
# 4           Brookfield                    WI                    53045
#
#   contact_address_country animal_id animal_type
# 0                      US  50398452         cat
# 1                      US  50398488         dog
# 2                      US  50398489         cat
# 3                      US  50398490         dog
# 4                      US  50398491         cat
#
# [5 rows x 48 columns]

# %% [markdown]
# ## Merge DFs to One and Send to MongoDB

# %%
# all_df = pd.merge(animal_df, org2_df,  how= "inner", on=["organization_id", "organization_id"])
all_df = pd.merge(animal_conv_df, org_zip3_df, on=["organization_id", "organization_id"])

# %%
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# %%
db = client.rescue_angels_db

# %%
final_mongo_dict = all_df.to_dict("records")

# %%
# db.final_data.insert_many(final_mongo_dict)
