# %%
#!pip install requests
# Out:
# Requirement already satisfied: requests in /Users/jenniferdean/opt/anaconda3/lib/python3.8/site-packages (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/jenniferdean/opt/anaconda3/lib/python3.8/site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/jenniferdean/opt/anaconda3/lib/python3.8/site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jenniferdean/opt/anaconda3/lib/python3.8/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/jenniferdean/opt/anaconda3/lib/python3.8/site-packages (from requests) (1.25.11)

# %%
import requests 
import datetime
import base64

# %%
client_id = "3Ud8hCcYPzOVjoAMQCvpuWD5cGpJ1BA60gILI6SIV8BFkPNRRD"
client_secret = "WMIebvADWcbwnEcTEFxo3ts52K5yV1M8PcA5Xs5H"

# %%
# Do a look up for a token 
# This token is for future requests

# %% [markdown]
# # Create your Access Token from the Client ID above

# %%
token_url = "https://api.petfinder.com/v2/oauth2/token"

method = "POST"

token_data = {
    "grant_type" : "client_credentials",
    "client_id" : client_id,
    "client_secret" : client_secret
}

# %%
r = requests.post(token_url, data = token_data)
#print(r.json())
valid_request = r.status_code in range(200, 299)
# Out:
# {'token_type': 'Bearer', 'expires_in': 3600, 'access_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..Y8TdqVIROnE4AtYV5qXceDRNDKnlqUvGjaEJ5lLjV7HjE0WJR4DnTmkrfkg5aqYBbztjdcOuD0N3DfhKe3mB4UL2PoazcB-3bN3lSdpzYY-A4xNV6V4FZZ5jq30ybdUEVH1HSVjcymUNS9pcD2NH-OYfn1uJIK1Fm6HD90FcXHxwVUXa1ycJA3MHqdLMPv7DsVn-u1CIwEDbWQOnIT9J_jysq0C1_91vXa5VRg00sgwH2fqCmgI3_IQUvNZbh_nByqGP7lKfOwUZkux-mBikGYge3tTqM4O6XWvKELd3sZMy9BVJcrBr9tAaMlMS_5bT-UoSv3PANZ1pNRTACzDkrQ'}

# %%
if valid_request: 
    token_response_data = r.json()
    now = datetime.datetime.now()
    access_token = token_response_data['access_token']
    expires_in = token_response_data['expires_in'] # seconds 
    expires = now + datetime.timedelta(seconds = expires_in)
    did_expire = expires < now

# %%
access_token # This is your raw Access Token used for the calls below
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..Y8TdqVIROnE4AtYV5qXceDRNDKnlqUvGjaEJ5lLjV7HjE0WJR4DnTmkrfkg5aqYBbztjdcOuD0N3DfhKe3mB4UL2PoazcB-3bN3lSdpzYY-A4xNV6V4FZZ5jq30ybdUEVH1HSVjcymUNS9pcD2NH-OYfn1uJIK1Fm6HD90FcXHxwVUXa1ycJA3MHqdLMPv7DsVn-u1CIwEDbWQOnIT9J_jysq0C1_91vXa5VRg00sgwH2fqCmgI3_IQUvNZbh_nByqGP7lKfOwUZkux-mBikGYge3tTqM4O6XWvKELd3sZMy9BVJcrBr9tAaMlMS_5bT-UoSv3PANZ1pNRTACzDkrQ'

# %%
token_data = {
    "Authorization" :f"Bearer {access_token}"
}

# %% [markdown]
# # Below is the query structure

# %%
query_url = "https://api.petfinder.com/v2/animals?type=dog&page=2"

response = requests.get(query_url, headers = token_data)

print(response.text)
# Out:
# {"animals":[{"id":50300636,"organization_id":"WA642","url":"https:\/\/www.petfinder.com\/dog\/tallulah-ozette-50300636\/wa\/benton-city\/the-pit-bull-pen-wa642\/?referrer_id=cd5242ea-963a-4b60-8b2c-b458aeb14609","type":"Dog","species":"Dog","breeds":{"primary":"Terrier","secondary":null,"mixed":false,"unknown":false},"colors":{"primary":"White \/ Cream","secondary":"Gray \/ Blue \/ Silver","tertiary":null},"age":"Young","gender":"Female","size":"Small","coat":null,"attributes":{"spayed_neutered":true,"house_trained":false,"declawed":null,"special_needs":false,"shots_current":true},"environment":{"children":null,"dogs":null,"cats":null},"tags":[],"name":"Tallulah\/Ozette","description":null,"organization_animal_id":"TPBP-A-80","photos":[{"small":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300636\/1\/?bust=1610918133\u0026width=100","medium":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300636\/1\/?bust=1610918133\u0026width=300","large":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300636\/1\/?bust=1610918133\u0026width=600","full":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300636\/1\/?bust=1610918133"}],"primary_photo_cropped":{"small":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300636\/1\/?bust=1610918133\u0026width=300","medium":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300636\/1\/?bust=1610918133\u0026width=450","large":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300636\/1\/?bust=1610918133\u0026width=600","full":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300636\/1\/?bust=1610918133"},"videos":[],"status":"adoptable","status_changed_at":"2021-01-17T21:05:11+0000","published_at":"2021-01-17T21:05:11+0000","distance":null,"contact":{"email":"thepitbullpen@gmail.com","phone":"(509) 588-9993","address":{"address1":"22206 E Kennedy Rd","address2":null,"city":"Benton City","state":"WA","postcode":"99320","country":"US"}},"_links":{"self":{"href":"\/v2\/animals\/50300636"},"type":{"href":"\/v2\/types\/dog"},"organization":{"href":"\/v2\/organizations\/wa642"}}},{"id":50300635,"organization_id":"NJ955","url":"https:\/\/www.petfinder.com\/dog\/diego-50300635\/mo\/st-clair\/great-pyrenees-rescue-of-missouri-nj955\/?referrer_id=cd5242ea-963a-4b60-8b2c-b458aeb14609","type":"Dog","species":"Dog","breeds":{"primary":"Great Pyrenees","secondary":null,"mixed":false,"unknown":false},"colors":{"primary":"White \/ Cream","secondary":null,"tertiary":null},"age":"Adult","gender":"Male","size":"Large","coat":null,"attributes":{"spayed_neutered":false,"house_trained":false,"declawed":null,"special_needs":false,"shots_current":true},"environment":{"children":null,"dogs":null,"cats":null},"tags":[],"name":"Diego","description":"Diego is a Great Pyrenees\/Aussie mix. He came into rescue when he was hit by a car and finder took...","organization_animal_id":"GPRM-A-22","photos":[{"small":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300635\/1\/?bust=1610918130\u0026width=100","medium":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300635\/1\/?bust=1610918130\u0026width=300","large":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300635\/1\/?bust=1610918130\u0026width=600","full":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300635\/1\/?bust=1610918130"},{"small":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300635\/3\/?bust=1610918131\u0026width=100","medium":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300635\/3\/?bust=1610918131\u0026width=300","large":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300635\/3\/?bust=1610918131\u0026width=600","full":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300635\/3\/?bust=1610918131"},{"small":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300635\/2\/?bust=1610918133\u0026width=100","medium":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50300635\/2\/?bust=1610918133\u0026width=300","large":"https:\/\/dl5zpy ...
