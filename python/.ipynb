# %% [markdown]
# ## Petfinder API Call

# %%
#!pip install requests

# %%
import requests 
import datetime
import base64
from pprint import pprint

# %%
client_id = "3Ud8hCcYPzOVjoAMQCvpuWD5cGpJ1BA60gILI6SIV8BFkPNRRD"
client_secret = "WMIebvADWcbwnEcTEFxo3ts52K5yV1M8PcA5Xs5H"

# %%
# Do a look up for a token 
# This token is for future requests

# %% [markdown]
# # Create your Access Token from the Client ID above

# %%
token_url = "https://api.petfinder.com/v2/oauth2/token"

method = "POST"

token_data = {
    "grant_type" : "client_credentials",
    "client_id" : client_id,
    "client_secret" : client_secret
}

# %%
r = requests.post(token_url, data = token_data)
#print(r.json())
valid_request = r.status_code in range(200, 299)

# %%
if valid_request: 
    token_response_data = r.json()
    now = datetime.datetime.now()
    access_token = token_response_data['access_token']
    expires_in = token_response_data['expires_in'] # seconds 
    expires = now + datetime.timedelta(seconds = expires_in)
    did_expire = expires < now

# %%
access_token # This is your raw Access Token used for the calls below
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..h_68OtH3WkGDjBFb9o64zXhS9VgzOUe3h_n4UoWJrXan9-rd2mln3FIef6KHcEaDMp1tH526vgkN2T5wnoukSFYGx6Uah1zgxfGgQ4-WoUumv8HTCcJYtXZHkwOhJCLwdehO-ShBG5YiBDZ_lCvmT7eZaxmX_ZgGtkjWNwq6QuyxDr35VjLCJRCbBytQnNRnmvf1pcP_4xSK3yC_9OIV5NB7nLegsTefxLT9XT6xqZtLDAR9w8M5lch4sc16koJmT0ehOLBTAgPhcxzkopUuOOfy14ogpYHtn-rCLNgqalz4ZTRk7GYeK2hWeSYy50avvScdbunSfsuZ3aXMBvKpVQ'

# %%
token_data = {
    "Authorization" :f"Bearer {access_token}"
}

# %% [markdown]
# # Below is the query structure

# %%
query_url = "https://api.petfinder.com/v2/animals?type=dog&page=2"

response = requests.get(query_url, headers = token_data)

print(response.text)
# Out:
# {"animals":[{"id":50318863,"organization_id":"GA76","url":"https:\/\/www.petfinder.com\/dog\/rosemary-50318863\/ga\/winder\/pup-and-cat-co-ga76\/?referrer_id=cd5242ea-963a-4b60-8b2c-b458aeb14609","type":"Dog","species":"Dog","breeds":{"primary":"Hound","secondary":"Doberman Pinscher","mixed":true,"unknown":false},"colors":{"primary":null,"secondary":null,"tertiary":null},"age":"Adult","gender":"Female","size":"Medium","coat":null,"attributes":{"spayed_neutered":false,"house_trained":true,"declawed":null,"special_needs":false,"shots_current":false},"environment":{"children":true,"dogs":true,"cats":null},"tags":[],"name":"Rosemary","description":"Rosemary is a super sweet girl who would make a wonderful addition to any family. She\u0026amp;#39;s 3 years old, 35...","organization_animal_id":"16293095-Rosemary112020","photos":[{"small":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/photos\/pets\/50318863\/1\/?bust=1611112159\u0026width=100","medium":"https:\/\/dl5zpyw5k3jeb.cloudfront.net\/pho
# ...

# %%
pprint(response.json())
# Out:
# {'animals': [{'_links': {'organization': {'href': '/v2/organizations/ga76'},
#                          'self': {'href': '/v2/animals/50318863'},
#                          'type': {'href': '/v2/types/dog'}},
#               'age': 'Adult',
#               'attributes': {'declawed': None,
#                              'house_trained': True,
#                              'shots_current': False,
#                              'spayed_neutered': False,
#                              'special_needs': False},
#               'breeds': {'mixed': True,
#                          'primary': 'Hound',
#                          'secondary': 'Doberman Pinscher',
#                          'unknown': False},
#               'coat': None,
#               'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#               'contact': {'address': {'address1': None,
#                                       'address2': None,
#                                       'city': 'Winder',
# ...
