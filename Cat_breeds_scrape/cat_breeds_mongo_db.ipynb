# %%
# Dependencies
import pymongo
import pandas as pd
import dnspython
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-758b8a2b058a> in <module>
#       2 import pymongo
#       3 import pandas as pd
# ----> 4 import dnspython
#
# ModuleNotFoundError: No module named 'dnspython'

# %%
# Initialize PyMongo to work with MongoDBs
#conn = 'mongodb+srv://dbDeepa:DeepaRutgers@cluster0.s0gp3.mongodb.net/test'
conn = 'mongodb+srv://dbDeepa:DeepaRutgers@cluster0.s0gp3.mongodb.net/rescue_angels_db?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.rescue_angels_db
cat_breeds_collection = db.cat_breeds

# %%
# Read the csv file
url = 'cat_breeds_all_clean.csv'
cat_breeds_df = pd.read_csv(url)
cat_breeds_df = cat_breeds_df.fillna('')
cat_breeds_df.head()
# Out:
#     breed_name                                              image  \
# 0    Singapura  https://d17fnq9dkz9hgj.cloudfront.net/breed-up...
# 1     Munchkin  https://d17fnq9dkz9hgj.cloudfront.net/breed-up...
# 2   Abyssinian  https://d17fnq9dkz9hgj.cloudfront.net/breed-up...
# 3  Cornish Rex  https://d17fnq9dkz9hgj.cloudfront.net/breed-up...
# 4    Devon Rex  https://d17fnq9dkz9hgj.cloudfront.net/breed-up...
#
#                                          description  \
# 0  The appearance of an alert healthy small- to m...
# 1  The Munchkin cat has no problem getting around...
# 2  The Abyssinian is often a colorful cat with a ...
# 3  The Cornish Rex is distinguished from all othe...
# 4  The Devon Rex is a breed of unique appearance....
#
#                                               weight weight_group  \
# 0  Small, with males weighing 6 to 8 pounds and f...        small
# 1            Small with weight between 5 to 9 pounds        small
# ...

# %%
# add cat breed to mondo db
for jdict in cat_breeds_df.to_dict(orient='records'):
    print(jdict)
    cat_breeds_collection.insert_one(jdict)
# Out:
# {'breed_name': 'Singapura', 'image': 'https://d17fnq9dkz9hgj.cloudfront.net/breed-uploads/2018/08/singapura-detail-1.jpg?bust=1540317126&width=355', 'description': 'The appearance of an alert healthy small- to medium-sized muscular bodied cat with noticeably large eyes and ears in proportion to its head. Cat to have the illusion of refined delicate coloring.', 'weight': 'Small, with males weighing 6 to 8 pounds and females weighing 5 to 6 pounds', 'weight_group': 'small', 'color_options': "['Sepia']", 'life_expectancy': '9 to 15 years', 'coat_length': 'Shorthair', 'characteristics': 'Warm beige, ticked coat; large expressive eyes; small cat', 'personality': 'Sweet, demanding, affectionate and occasionally bossy', 'playfullness': 5, 'activity': 4, 'friendliness_others': 3, 'friendliness_children': 3, 'grooming': 1, 'vocality': 2, 'attention': 5, 'affection': 4, 'docility': 1, 'intelligence': 4, 'independence': 3, 'hardiness': 2}
# ...
