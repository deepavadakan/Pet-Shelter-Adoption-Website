# %%
import petpy
from config import API_key, API_secret
import json
import pymongo
from petpy import Petfinder

# %%
pf = Petfinder(key=API_key, secret=API_secret)

# %%
# organizations = pf.organizations(results_per_page=100, pages=100, return_df=True)

# %%
# organizations.head()

# %%
# Returning data for a single animal type
dogs = pf.animal_types('dog')
dogs
# Out:
# {'type': {'name': 'Dog',
#   'coats': ['Hairless', 'Short', 'Medium', 'Long', 'Wire', 'Curly'],
#   'colors': ['Apricot / Beige',
#    'Bicolor',
#    'Black',
#    'Brindle',
#    'Brown / Chocolate',
#    'Golden',
#    'Gray / Blue / Silver',
#    'Harlequin',
#    'Merle (Blue)',
#    'Merle (Red)',
#    'Red / Chestnut / Orange',
#    'Sable',
#    'Tricolor (Brown, Black, & White)',
#    'White / Cream',
#    'Yellow / Tan / Blond / Fawn'],
#   'genders': ['Male', 'Female'],
#   '_links': {'self': {'href': '/v2/types/dog'},
#    'breeds': {'href': '/v2/types/dog/breeds'}}}}

# %%
animals = pf.animals()
animals
# Out:
# {'animals': [{'id': 50347401,
#    'organization_id': 'IA223',
#    'url': 'https://www.petfinder.com/dog/alfalfa-50347401/ia/clear-lake/patriots-for-pets-rescue-and-shelter-inc-ia223/?referrer_id=14437645-0638-40b7-a961-ffc493744179',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Australian Cattle Dog / Blue Heeler',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'White / Cream',
#     'secondary': 'Yellow / Tan / Blond / Fawn',
#     'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Alfalfa',
# ...

# %%
animals2 = pf.animals(results_per_page=100, pages=100, return_df=True)
# Out:
# C:\Users\kaldm\anaconda3\envs\PythonData\lib\site-packages\petpy\api.py:1049: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   results_df = json_normalize(results[key])

# %%
animals2.head()
# Out:
#          id organization_id  \
# 0  50347401           IA223
# 1  50347364            LA48
# 2  50347253          CA1855
# 3  50347415           AZ556
# 4  50347409           AZ556
#
#                                                  url type species    age  \
# 0  https://www.petfinder.com/dog/alfalfa-50347401...  Dog     Dog   Baby
# 1  https://www.petfinder.com/cat/peter-50347364/l...  Cat     Cat   Baby
# 2  https://www.petfinder.com/dog/mastiff-boy-5034...  Dog     Dog  Adult
# 3  https://www.petfinder.com/cat/moon-50347415/az...  Cat     Cat  Young
# 4  https://www.petfinder.com/cat/olaf-50347409/az...  Cat     Cat  Young
#
#    gender         size   coat  \
# 0    Male       Medium  Short
# 1    Male       Medium  Short
# 2    Male  Extra Large  Short
# 3  Female       Medium   None
# 4    Male       Medium   None
#
#                                                tags  ...  \
# 0                                                []  ...
# ...

# %%
index = animals2.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 10000
