# %%
import petpy
from config import API_key, API_secret
import json
import pymongo

# %%
pf = petpy.Petfinder(key=API_key, secret=API_secret)

# %%
organizations = pf.organizations(results_per_page=100, pages=100, return_df=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\petpy\api.py:1049: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   results_df = json_normalize(results[key])

# %%
organizations.head()
# Out:
#       id                                               name  \
# 0  PA912                         The Shelter Animal Project
# 1  GA762                        Special Touch Animal Rescue
# 2  TX876                Gina's Heart of Gold Reptile Rescue
# 3  OH749                     Purr-fect Companions Sanctuary
# 4  MO556  Montgomery City Animal Shelter/Project Preciou...
#
#                              email           phone  \
# 0           tsapadoption@gmail.com            None
# 1               STARRadopt@aol.com  (404) 983-3581
# 2          gdisteldorf@comcast.net  (713) 329-9304
# 3       purrfectcompanions@att.net    216-671-6369
# 4  projectpreciouspaws@hotmail.com  1-573-310-4979
#
#                                                  url website  \
# 0  https://www.petfinder.com/member/us/pa/fairles...    None
# 1  https://www.petfinder.com/member/us/ga/acworth...    None
# 2  https://www.petfinder.com/member/us/tx/houston...    None
# 3  https://www.petfinder.com/member/us/oh/lakewoo...    None
# 4  https://www.petfinder.com/member/us/mo/montgom...    None
#
#                                    mission_statement  \
# 0                                               None
# 1  We are a private foster home group. We are NOT...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                               photos distance  \
# 0  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     None
# 1                                                 []     None
# 2                                                 []     None
# 3                                                 []     None
# 4  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     None
#
#     address.address1  ... hours.saturday hours.sunday adoption.policy  \
# 0          PO Box 24  ...           None         None            None
# 1               None  ...           None         None            None
# 2               None  ...           None         None            None
# 3     P.O.Box 770992  ...           None         None            None
# 4  915 Benton Street  ...           None         None            None
#
#   adoption.url social_media.facebook social_media.twitter  \
# 0         None                  None                 None
# 1         None                  None                 None
# 2         None                  None                 None
# 3         None                  None                 None
# 4         None                  None                 None
#
#   social_media.youtube social_media.instagram social_media.pinterest  \
# 0                 None                   None                   None
# 1                 None                   None                   None
# 2                 None                   None                   None
# 3                 None                   None                   None
# 4                 None                   None                   None
#
#   organization_id
# 0           pa912
# 1           ga762
# 2           tx876
# 3           oh749
# 4           mo556
#
# [5 rows x 30 columns]
