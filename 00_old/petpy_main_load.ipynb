# %%
import petpy
from config import API_key, API_secret
import json
import pymongo
import pprint
import time

# %%
pf = petpy.Petfinder(key=API_key, secret=API_secret)

# %%
organizations = pf.organizations(results_per_page=100, pages=100)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-6dbcc56e8b05> in <module>
# ----> 1 organizations = pf.organizations(results_per_page=100, pages=100)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/petpy/api.py in organizations(self, organization_id, name, location, distance, state, country, query, sort, results_per_page, pages, return_df)
#     687                                 },
#     688                                 params=params)
# --> 689                 _check_api_rate_exceeded(r.json())
#     690                 organizations = r.json()['organizations']
#     691                 max_pages = r.json()['pagination']['total_pages']
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/petpy/api.py in _check_api_rate_exceeded(r, exit_loop)
#    1115                 return True
#    1116             else:
# -> 1117                 raise RuntimeError(r['title'])
#
# RuntimeError: Rate Limit Exceeded

# %%
organizations
# Out:
# {'organizations': [{'id': 'PA912',
#    'name': 'The Shelter Animal Project',
#    'email': 'tsapadoption@gmail.com',
#    'phone': None,
#    'address': {'address1': 'PO Box 24',
#     'address2': None,
#     'city': 'Fairless Hills',
#     'state': 'PA',
#     'postcode': '19030',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/pa/fairless-hills/the-shelter-animal-project-pa912/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/44481/1/?bust=1511996149&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/44481/1/?bust=1511996149&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/44481/1/?bust=1511996149&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/44481/1/?bust=1511996149'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/pa912'},
#     'animals': {'href': '/v2/animals?organization=pa912'}}},
#   {'id': 'GA762',
#    'name': 'Special Touch Animal Rescue',
#    'email': 'STARRadopt@aol.com',
#    'phone': '(404) 983-3581',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Acworth',
#     'state': 'GA',
#     'postcode': '30102',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/ga/acworth/special-touch-animal-rescue-ga762/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': 'We are a private foster home group. We are NOT a shelter or facility. Our dogs come from licensed animal...',
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ga762'},
#     'animals': {'href': '/v2/animals?organization=ga762'}}},
#   {'id': 'TX876',
#    'name': "Gina's Heart of Gold Reptile Rescue",
#    'email': 'gdisteldorf@comcast.net',
#    'phone': '(713) 329-9304',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Houston',
#     'state': 'TX',
#     'postcode': '77080',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/tx/houston/ginas-heart-of-gold-reptile-rescue-tx876/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/tx876'},
#     'animals': {'href': '/v2/animals?organization=tx876'}}},
#   {'id': 'OH749',
#    'name': 'Purr-fect Companions Sanctuary',
#    'email': 'purrfectcompanions@att.net',
#    'phone': '216-671-6369',
#    'address': {'address1': 'P.O.Box 770992',
#     'address2': None,
#     'city': 'Lakewood',
#     'state': 'OH',
#     'postcode': '44107',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/oh/lakewood/purr-fect-companions-sanctuary-oh749/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/oh749'},
#     'animals': {'href': '/v2/animals?organization=oh749'}}},
#   {'id': 'MO556',
#    'name': 'Montgomery City Animal Shelter/Project Precious Paws',
#    'email': 'projectpreciouspaws@hotmail.com',
#    'phone': '1-573-310-4979',
#    'address': {'address1': '915 Benton Street',
#     'address2': None,
#     'city': 'Montgomery City',
#     'state': 'MO',
#     'postcode': '63361',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/mo/montgomery-city/montgomery-city-animal-shelter-project-precious-paws-mo556/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/6/?bust=1511957123&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/6/?bust=1511957123&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/6/?bust=1511957123&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/6/?bust=1511957123'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/1/?bust=1497997052&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/1/?bust=1497997052&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/1/?bust=1497997052&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/1/?bust=1497997052'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/2/?bust=1497997052&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/2/?bust=1497997052&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/2/?bust=1497997052&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/2/?bust=1497997052'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/3/?bust=1497997053&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/3/?bust=1497997053&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/3/?bust=1497997053&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/3/?bust=1497997053'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/4/?bust=1497997053&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/4/?bust=1497997053&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/4/?bust=1497997053&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/4/?bust=1497997053'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/5/?bust=1497997054&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/5/?bust=1497997054&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/5/?bust=1497997054&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33008/5/?bust=1497997054'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/mo556'},
#     'animals': {'href': '/v2/animals?organization=mo556'}}},
#   {'id': 'IA233',
#    'name': 'Whispurring Hope Rescue',
#    'email': 'whispurringhoperescue@gmail.com',
#    'phone': '(563) 451-5399',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Dubuque',
#     'state': 'IA',
#     'postcode': '52001',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/ia/dubuque/whispurring-hope-rescue-ia233/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': 'http://whispurringhoperescue.weebly.com',
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': 'https://www.facebook.com/whispurringhope/',
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/45228/1/?bust=1511945845&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/45228/1/?bust=1511945845&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/45228/1/?bust=1511945845&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/45228/1/?bust=1511945845'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ia233'},
#     'animals': {'href': '/v2/animals?organization=ia233'}}},
#   {'id': 'AZ598',
#    'name': 'Arizona Shih Tzu and Small Breed Rescue',
#    'email': 'ASTSBR@Gmail.com',
#    'phone': None,
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Phoenix',
#     'state': 'AZ',
#     'postcode': '85032',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/az/phoenix/arizona-shih-tzu-and-small-breed-rescue-az598/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': 'http://azshihtzurescue.com',
#    'mission_statement': 'Arizona Shih Tzu and Small Breed Rescue is a 501(c)(3) not for profit rescue\xa0dedicated to the rescuing, rehabilitating and...',
#    'adoption': {'policy': 'PLEASE FILL OUT AN APPLICATION BEFORE MAKING AND INQUIRY\r\nIf you see a rescue dog that you would be interested...',
#     'url': 'https://www.shelterluv.com/matchme/adopt/AZST/Dog'},
#    'social_media': {'facebook': 'https://www.facebook.com/arizonashihtzuandsmallbreedrescue/',
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/46572/2/?bust=1497677458&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/46572/2/?bust=1497677458&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/46572/2/?bust=1497677458&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/46572/2/?bust=1497677458'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/46572/1/?bust=1497677457&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/46572/1/?bust=1497677457&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/46572/1/?bust=1497677457&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/46572/1/?bust=1497677457'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/46572/3/?bust=1497677458&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/46572/3/?bust=1497677458&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/46572/3/?bust=1497677458&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/46572/3/?bust=1497677458'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/az598'},
#     'animals': {'href': '/v2/animals?organization=az598'}}},
#   {'id': 'KY342',
#    'name': 'Webster County Animal Services',
#    'email': 'webstercodogpound@att.net',
#    'phone': '(270) 639-7034',
#    'address': {'address1': '1919 HWY 132W',
#     'address2': None,
#     'city': 'Dixon',
#     'state': 'KY',
#     'postcode': '42409',
#     'country': 'US'},
#    'hours': {'monday': 'Closed',
#     'tuesday': '8am-3pm',
#     'wednesday': '8am-3pm',
#     'thursday': '8am-3pm',
#     'friday': '8am-3pm',
#     'saturday': '8am-11:30am',
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/ky/dixon/webster-county-animal-services-ky342/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': 'Our objective is to get as many dogs into loving forever homes as possible. We have been a no-kill shelter...',
#    'adoption': {'policy': 'Adoption fees: $95 in county\r\n\r\n(includes spay/neuter voucher, rabies vaccination and county dog tag)\r\n\r\n$30 already Spayed or Neutered price\r\n\r\n\xa0...',
#     'url': None},
#    'social_media': {'facebook': 'https://www.facebook.com/Webster-County-Animal-Care-and-Control-506997629446080/',
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/21920/1/?bust=1511949380&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/21920/1/?bust=1511949380&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/21920/1/?bust=1511949380&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/21920/1/?bust=1511949380'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ky342'},
#     'animals': {'href': '/v2/animals?organization=ky342'}}},
#   {'id': 'MN443',
#    'name': 'Kitten Care Group MN',
#    'email': 'kittencaregroupmn@gmail.com',
#    'phone': None,
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Kasota',
#     'state': 'MN',
#     'postcode': '56050',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/mn/kasota/kitten-care-group-mn-mn443/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/47878/1/?bust=1510237839&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/47878/1/?bust=1510237839&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/47878/1/?bust=1510237839&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/47878/1/?bust=1510237839'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/mn443'},
#     'animals': {'href': '/v2/animals?organization=mn443'}}},
#   {'id': 'CA2464',
#    'name': "Deb's Claws and Paws Rescue",
#    'email': 'debjackson1@comcast.net',
#    'phone': '(530) 763-2770',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Yuba City',
#     'state': 'CA',
#     'postcode': '95991',
#     'country': 'US'},
#    'hours': {'monday': '10-7',
#     'tuesday': '10-7',
#     'wednesday': '10-7',
#     'thursday': '10-7',
#     'friday': '10-7',
#     'saturday': '10-7',
#     'sunday': '11-5'},
#    'url': 'https://www.petfinder.com/member/us/ca/yuba-city/debs-claws-and-paws-rescue-ca2464/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ca2464'},
#     'animals': {'href': '/v2/animals?organization=ca2464'}}},
#   {'id': 'TX1828',
#    'name': 'No Place Like Home',
#    'email': 'info@nplhpetsitters.com',
#    'phone': '(817) 707-4239',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Burleson',
#     'state': 'TX',
#     'postcode': '76028',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/tx/burleson/no-place-like-home-tx1828/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': 'No Place Like Home is a small, not for profit FELINE ONLY rescue group dedicated to saving the lives of...',
#    'adoption': {'policy': 'Since our cats are in foster homes, we ask that you please contact us for an appointment to visit any...',
#     'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/tx1828'},
#     'animals': {'href': '/v2/animals?organization=tx1828'}}},
#   {'id': 'CA458',
#    'name': 'Second Chance Pet Rescue',
#    'email': 'info@secondchancepetrescue.org',
#    'phone': '(530) 824-1985',
#    'address': {'address1': 'PO Box 938',
#     'address2': None,
#     'city': 'Corning',
#     'state': 'CA',
#     'postcode': '96021',
#     'country': 'US'},
#    'hours': {'monday': 'By appointment only',
#     'tuesday': 'By appointment only',
#     'wednesday': 'By appointment only',
#     'thursday': 'By appointment only',
#     'friday': 'By appointment only',
#     'saturday': 'By appointment only',
#     'sunday': 'By appointment only'},
#    'url': 'https://www.petfinder.com/member/us/ca/corning/second-chance-pet-rescue-ca458/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': 'http://www.secondchancepetrescue.org',
#    'mission_statement': 'To save dogs in Tehama County.',
#    'adoption': {'policy': 'Adoption fees range between $50 and $150, depending on the age and size of the dog. Spay/neuter surgery, vaccinations, flea...',
#     'url': 'https://www.secondchancepetrescue.org/adopt/'},
#    'social_media': {'facebook': 'https://www.facebook.com/secondchancepetrescue/',
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/27720/1/?bust=1546715043&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/27720/1/?bust=1546715043&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/27720/1/?bust=1546715043&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/27720/1/?bust=1546715043'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ca458'},
#     'animals': {'href': '/v2/animals?organization=ca458'}}},
#   {'id': 'CA1499',
#    'name': 'All Krazy for Kats, INC.',
#    'email': 'michele@krazyforkats.com',
#    'phone': '(818) 527-5287',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Woodland Hills',
#     'state': 'CA',
#     'postcode': '91364',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/ca/woodland-hills/all-krazy-for-kats-inc-ca1499/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': 'http://www.krazyforkats.org',
#    'mission_statement': 'Krazy For Kats, Inc. is a 501 C3 non-profit dedicated to saving the lives of the millions cats and kittens...',
#    'adoption': {'policy': 'KRAZY FOR KATS ADOPTION PROTOCOL:\r\n\r\nThere will be an in-depth phone consultation with all potential adopters. We require a home...',
#     'url': 'https://www.krazyforkats.org/adoptions'},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/27252/1/?bust=1589659811&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/27252/1/?bust=1589659811&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/27252/1/?bust=1589659811&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/27252/1/?bust=1589659811'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ca1499'},
#     'animals': {'href': '/v2/animals?organization=ca1499'}}},
#   {'id': 'WI151',
#    'name': 'Crazy Ladies Cat Rescue',
#    'email': 'Imems@yahoo.com',
#    'phone': '(920) 290-5571',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Berlin',
#     'state': 'WI',
#     'postcode': '54923',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/wi/berlin/crazy-ladies-cat-rescue-wi151/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/wi151'},
#     'animals': {'href': '/v2/animals?organization=wi151'}}},
#   {'id': 'CA1070',
#    'name': 'Miniature Schnauzers & Friends Rescue',
#    'email': 'msfrescue@gmail.com',
#    'phone': None,
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Redondo Beach',
#     'state': 'CA',
#     'postcode': '90278',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/ca/redondo-beach/miniature-schnauzers-and-friends-rescue-ca1070/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': 'http://www.msfr.org',
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ca1070'},
#     'animals': {'href': '/v2/animals?organization=ca1070'}}},
#   {'id': 'PA546',
#    'name': 'Pittsburgh Rat Lovers Club',
#    'email': 'kcyann@aol.com',
#    'phone': '412-708-7919   ',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Pittsburgh',
#     'state': 'PA',
#     'postcode': '15211',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/pa/pittsburgh/pittsburgh-rat-lovers-club-pa546/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/1/?bust=1504267446&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/1/?bust=1504267446&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/1/?bust=1504267446&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/1/?bust=1504267446'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/2/?bust=1504267446&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/2/?bust=1504267446&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/2/?bust=1504267446&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/2/?bust=1504267446'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/3/?bust=1504267447&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/3/?bust=1504267447&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/3/?bust=1504267447&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/3/?bust=1504267447'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/4/?bust=1504267448&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/4/?bust=1504267448&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/4/?bust=1504267448&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/4/?bust=1504267448'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/5/?bust=1504267448&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/5/?bust=1504267448&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/5/?bust=1504267448&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/5/?bust=1504267448'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/6/?bust=1504267449&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/6/?bust=1504267449&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/6/?bust=1504267449&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36772/6/?bust=1504267449'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/pa546'},
#     'animals': {'href': '/v2/animals?organization=pa546'}}},
#   {'id': 'OH966',
#    'name': 'Hartman Veterinary Hospital',
#    'email': 'HartmanVet3924@gmail.com',
#    'phone': '(419) 385-7433',
#    'address': {'address1': '3924 Airport Hwy',
#     'address2': None,
#     'city': 'Toledo',
#     'state': 'OH',
#     'postcode': '43615',
#     'country': 'US'},
#    'hours': {'monday': '9 AM - 4 PM',
#     'tuesday': 'CLOSED',
#     'wednesday': '9 AM - 4 PM',
#     'thursday': '9 AM - 4 PM',
#     'friday': '9 AM - 4 PM',
#     'saturday': '9 AM - 11 AM',
#     'sunday': 'CLOSED'},
#    'url': 'https://www.petfinder.com/member/us/oh/toledo/hartman-veterinary-hospital-oh966/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': 'Listed below are the requirements for adopting a cat or kitten from our hospital. Please review\xa0these points before you...',
#    'adoption': {'policy': 'The adoption fee for our cats is $50-75 (kittens $150). It is also non-refundable. If a cat/kitten is not already...',
#     'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/40875/1/?bust=1551453102&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/40875/1/?bust=1551453102&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/40875/1/?bust=1551453102&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/40875/1/?bust=1551453102'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/oh966'},
#     'animals': {'href': '/v2/animals?organization=oh966'}}},
#   {'id': 'OH459',
#    'name': 'Second Chance Rescue',
#    'email': 'secchancerescue@aol.com',
#    'phone': None,
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Bellbrook',
#     'state': 'OH',
#     'postcode': '45305',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/oh/bellbrook/second-chance-rescue-oh459/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': 'Second Chance Rescue is a non-profit organization formed to promote the rescue, foster, and placement of homeless companion animals into...',
#    'adoption': {'policy': 'Adopting A Friend:\r\n\r\nIf you see an animal that you are interested in, please send us an e-mail at secchancerescue@aol.com,...',
#     'url': None},
#    'social_media': {'facebook': 'http://www.facebook.com/secondchancerescuedayton',
#     'twitter': None,
#     'youtube': 'https://www.youtube.com/watch?v=ybN50aRZjq0',
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/35430/1/?bust=1503704008&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/35430/1/?bust=1503704008&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/35430/1/?bust=1503704008&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/35430/1/?bust=1503704008'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/oh459'},
#     'animals': {'href': '/v2/animals?organization=oh459'}}},
#   {'id': 'NM12',
#    'name': 'Raton Humane Society',
#    'email': 'blazingseven@bacavalley.com',
#    'phone': '(575)445-9328',
#    'address': {'address1': 'P.O. Box 1321',
#     'address2': '1108 South 5th Street',
#     'city': 'Raton',
#     'state': 'NM',
#     'postcode': '87740',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/nm/raton/raton-humane-society-nm12/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/nm12'},
#     'animals': {'href': '/v2/animals?organization=nm12'}}},
#   {'id': 'MI649',
#    'name': 'Purrfect Kitties',
#    'email': 'Quincyone2@aol.com',
#    'phone': '517-394-4955',
#    'address': {'address1': '1023 Shirley St.',
#     'address2': None,
#     'city': 'Lansing',
#     'state': 'MI',
#     'postcode': '48911',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/mi/lansing/purrfect-kitties-mi649/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/mi649'},
#     'animals': {'href': '/v2/animals?organization=mi649'}}},
#   {'id': 'OR248',
#    'name': 'Rose City Fox Terrier Rescue, Inc.',
#    'email': 'info@rosecityfoxterrierrescue.com',
#    'phone': None,
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Portland',
#     'state': 'OR',
#     'postcode': '97266',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/or/portland/rose-city-fox-terrier-rescue-inc-or248/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': 'http://www.rosecityfoxterrierrescue.com',
#    'mission_statement': 'Rose City Fox Terrier Rescue, Inc. is a Wire Haired Fox Terrier and Smooth Fox Terrier dog rescue based in...',
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36400/1/?bust=1510521777&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36400/1/?bust=1510521777&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36400/1/?bust=1510521777&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/36400/1/?bust=1510521777'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/or248'},
#     'animals': {'href': '/v2/animals?organization=or248'}}},
#   {'id': 'NJ363',
#    'name': 'Here Kitty Kitty',
#    'email': 'lmeowser1@gmail.com',
#    'phone': '(862) 668-4454',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Paterson',
#     'state': 'NJ',
#     'postcode': '07504',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/nj/paterson/here-kitty-kitty-nj363/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': 'https://www.herekittykittynj.org',
#    'mission_statement': 'Here Kitty Kitty NJ is a nonprofit 501(c)(3) rescue and adoption organization in Northern NJ dedicated to the rescue and...',
#    'adoption': {'policy': 'Applicants wishing to adopt a cat or kitten are carefully screened prior to adoption. They need to complete our detailed...',
#     'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/34017/1/?bust=1511964095&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/34017/1/?bust=1511964095&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/34017/1/?bust=1511964095&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/34017/1/?bust=1511964095'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/nj363'},
#     'animals': {'href': '/v2/animals?organization=nj363'}}},
#   {'id': 'LA260',
#    'name': 'Second Chance Paws',
#    'email': 'secondchancepaws@yahoo.com',
#    'phone': None,
#    'address': {'address1': 'P O Box 1224',
#     'address2': None,
#     'city': 'Crowley',
#     'state': 'LA',
#     'postcode': '70527',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/la/crowley/second-chance-paws-la260/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': 'Second Chance Paws is in need of fosters.\xa0 Please consider being a foster parent.\r\n\r\n\r\n\t\xa0\r\n\r\n\r\n\t\xa0\r\n\r\n\r\n\t\xa0\r\n\r\n\r\n\r\n\tWe are a group of ordinary...',
#    'adoption': {'policy': 'A pet is a special friend that shares its life with us.\xa0 It gives us unconditional love, which at times...',
#     'url': 'https://form.jotform.com/90346801635153'},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/31340/1/?bust=1511950225&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/31340/1/?bust=1511950225&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/31340/1/?bust=1511950225&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/31340/1/?bust=1511950225'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/la260'},
#     'animals': {'href': '/v2/animals?organization=la260'}}},
#   {'id': 'CA1587',
#    'name': 'Cloud 10 Cat Rescue',
#    'email': 'adoptme@cloud10catrescue.com',
#    'phone': '951-346-9100 ',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Riverside',
#     'state': 'CA',
#     'postcode': '92508',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/ca/riverside/cloud-10-cat-rescue-ca1587/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/27332/1/?bust=1504297280&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/27332/1/?bust=1504297280&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/27332/1/?bust=1504297280&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/27332/1/?bust=1504297280'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ca1587'},
#     'animals': {'href': '/v2/animals?organization=ca1587'}}},
#   {'id': 'NY1136',
#    'name': 'Tuff Tails Animal Rescue',
#    'email': 'info@tufftails.org',
#    'phone': None,
#    'address': {'address1': 'P.O. Box 117',
#     'address2': None,
#     'city': 'Levittown',
#     'state': 'NY',
#     'postcode': '11756',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/ny/levittown/tuff-tails-animal-rescue-ny1136/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': 'Hello!!\xa0 Please allow us to introduce ourselves - we are Tuff Tails Animal Rescue - a 100% no kill rescue...',
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/42597/2/?bust=1511994780&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/42597/2/?bust=1511994780&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/42597/2/?bust=1511994780&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/42597/2/?bust=1511994780'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/42597/1/?bust=1499456404&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/42597/1/?bust=1499456404&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/42597/1/?bust=1499456404&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/42597/1/?bust=1499456404'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ny1136'},
#     'animals': {'href': '/v2/animals?organization=ny1136'}}},
#   {'id': 'AR207',
#    'name': 'Warm Hearts Humane Society Inc,',
#    'email': 'warmhearts@earthlink.net',
#    'phone': '870-490-0883',
#    'address': {'address1': 'P.O. Box 535',
#     'address2': None,
#     'city': 'Mount Ida',
#     'state': 'AR',
#     'postcode': '71957',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/ar/mount-ida/warm-hearts-humane-society-inc-ar207/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/5/?bust=1511940029&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/5/?bust=1511940029&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/5/?bust=1511940029&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/5/?bust=1511940029'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/1/?bust=1505853514&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/1/?bust=1505853514&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/1/?bust=1505853514&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/1/?bust=1505853514'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/2/?bust=1505853515&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/2/?bust=1505853515&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/2/?bust=1505853515&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/2/?bust=1505853515'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/3/?bust=1505853515&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/3/?bust=1505853515&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/3/?bust=1505853515&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/3/?bust=1505853515'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/4/?bust=1505853516&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/4/?bust=1505853516&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/4/?bust=1505853516&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/4/?bust=1505853516'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/6/?bust=1505853517&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/6/?bust=1505853517&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/6/?bust=1505853517&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26363/6/?bust=1505853517'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ar207'},
#     'animals': {'href': '/v2/animals?organization=ar207'}}},
#   {'id': 'OH382',
#    'name': 'Allen County Dog Control',
#    'email': None,
#    'phone': '(419) 228-3700 ext. 8528',
#    'address': {'address1': '1165 Seriff Rd.',
#     'address2': None,
#     'city': 'Lima',
#     'state': 'OH',
#     'postcode': '45805',
#     'country': 'US'},
#    'hours': {'monday': '9am-5pm',
#     'tuesday': '9am-5pm',
#     'wednesday': '9am-5pm',
#     'thursday': '9am-5pm',
#     'friday': '9am-5pm',
#     'saturday': 'Closed',
#     'sunday': 'Closed'},
#    'url': 'https://www.petfinder.com/member/us/oh/lima/allen-county-dog-control-oh382/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/35377/1/?bust=1498242173&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/35377/1/?bust=1498242173&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/35377/1/?bust=1498242173&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/35377/1/?bust=1498242173'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/35377/2/?bust=1498242174&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/35377/2/?bust=1498242174&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/35377/2/?bust=1498242174&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/35377/2/?bust=1498242174'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/35377/3/?bust=1498242175&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/35377/3/?bust=1498242175&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/35377/3/?bust=1498242175&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/35377/3/?bust=1498242175'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/oh382'},
#     'animals': {'href': '/v2/animals?organization=oh382'}}},
#   {'id': 'OH51',
#    'name': 'GSP Care of Ohio Rescue Inc.',
#    'email': 'gspcareofohio@gmail.com',
#    'phone': '  ',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Streetsboro',
#     'state': 'OH',
#     'postcode': '44241',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/oh/streetsboro/gsp-care-of-ohio-rescue-inc-oh51/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/oh51'},
#     'animals': {'href': '/v2/animals?organization=oh51'}}},
#   {'id': 'UT212',
#    'name': 'South Utah Valley Animal Shelter',
#    'email': 'doglicensedivision@gmail.com',
#    'phone': '(801) 851-4080',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Spanish Fork',
#     'state': 'UT',
#     'postcode': '84660',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/ut/spanish-fork/south-utah-valley-animal-shelter-ut212/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ut212'},
#     'animals': {'href': '/v2/animals?organization=ut212'}}},
#   {'id': 'MI1026',
#    'name': 'Mosaic Farm',
#    'email': 'mosaicfarmrescue@gmail.com',
#    'phone': None,
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Grass Lake',
#     'state': 'MI',
#     'postcode': '49240',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/mi/grass-lake/mosaic-farm-mi1026/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
# ...
#     'city': 'Covelo',
#     'state': 'CA',
#     'postcode': '95428',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/ca/covelo/bones-pet-rescue-ca199/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ca199'},
#     'animals': {'href': '/v2/animals?organization=ca199'}}},
#   {'id': 'CT572',
#    'name': 'Perfect Imperfections',
#    'email': 'trishaperfectimperfections@gmail.com',
#    'phone': '(203) 232-1274',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Watertown',
#     'state': 'CT',
#     'postcode': '06795',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/ct/watertown/perfect-imperfections-ct572/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': 'http://www.perfectimperfections.wiki',
#    'mission_statement': None,
#    'adoption': {'policy': 'please fill out an application $350 adoption fee, dogs are UTD, spayed/neutered and microchipped',
#     'url': 'https://www.perfectimperfections.wiki/adoption-application'},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/47879/1/?bust=1517523483&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/47879/1/?bust=1517523483&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/47879/1/?bust=1517523483&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/47879/1/?bust=1517523483'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ct572'},
#     'animals': {'href': '/v2/animals?organization=ct572'}}},
#   {'id': 'MA447',
#    'name': 'German Shepherd Resource and Rescue Center, Inc.',
#    'email': 'adopt@germanshepherdcenter.org',
#    'phone': 'adopt@germanshepherdcenter.org',
#    'address': {'address1': 'P.O. Box 210',
#     'address2': None,
#     'city': 'Nahant',
#     'state': 'MA',
#     'postcode': '01908',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/ma/nahant/german-shepherd-resource-and-rescue-center-inc-ma447/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': 'Marlk your calendars because June 24th from 6-8PM is our 2nd annual Bark and Bid auction!\n\n\n\tit will be held...',
#    'adoption': {'policy': 'To be considered for adoption:\n\n\n\t\n\t\tReside in New England\n\t\n\t\tComplete an application\n\t\n\t\tTelephone Interview\n\t\n\t\tHome Visit Required.\n\n\n\tFor an application...',
#     'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/40617/1/?bust=1511951152&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/40617/1/?bust=1511951152&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/40617/1/?bust=1511951152&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/40617/1/?bust=1511951152'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ma447'},
#     'animals': {'href': '/v2/animals?organization=ma447'}}},
#   {'id': 'GA975',
#    'name': 'KATZ Feline Rescue',
#    'email': 'katzfelinerescue@gmail.com',
#    'phone': None,
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Augusta',
#     'state': 'GA',
#     'postcode': '30909',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/ga/augusta/katz-feline-rescue-ga975/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': 'http://www.katzfelinerescue.org',
#    'mission_statement': 'KATZ Feline Rescue is a non-profit 501(c)3 rescue in Augusta, Georgia. Our mission is to rescue, rehabilitate and find forever...',
#    'adoption': {'policy': 'If you are interested in adopting one of our kitties, please fill out an application on our website www.katzfelinerescue.org/adopt or...',
#     'url': 'http://www.katzfelinerescue.org/adopt'},
#    'social_media': {'facebook': 'https://www.facebook.com/KATZfelinerescue/',
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/49341/1/?bust=1565618833&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/49341/1/?bust=1565618833&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/49341/1/?bust=1565618833&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/49341/1/?bust=1565618833'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ga975'},
#     'animals': {'href': '/v2/animals?organization=ga975'}}},
#   {'id': 'MS76',
#    'name': 'Olive Branch Animal Shelter',
#    'email': 'keith.hamilton@obms.us',
#    'phone': '(662) 895-4582',
#    'address': {'address1': '7100 Stateline Rd.',
#     'address2': None,
#     'city': 'Olive Branch',
#     'state': 'MS',
#     'postcode': '38654',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/ms/olive-branch/olive-branch-animal-shelter-ms76/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': 'Olive Branch Animal Shelter offers adoptions for $65, cash or check only.  This covers spaying or neutering of your pet,...',
#     'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33106/1/?bust=1521033090&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33106/1/?bust=1521033090&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33106/1/?bust=1521033090&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/33106/1/?bust=1521033090'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ms76'},
#     'animals': {'href': '/v2/animals?organization=ms76'}}},
#   {'id': 'FL1171',
#    'name': 'LoveyLoaves Sanctuary',
#    'email': 'cheri@loveyloaves.org',
#    'phone': '(407) 494-2707',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Orlando',
#     'state': 'FL',
#     'postcode': '32825',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/fl/orlando/loveyloaves-sanctuary-fl1171/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': 'http://www.loveyloaves.org',
#    'mission_statement': 'LoveyLoaves is a special needs dog rescue based in Orlando, FL. We work to rehabilitate and re-home dogs who have...',
#    'adoption': {'policy': 'Prior to being turned over to their forever families, LoveyLoaves requires an adoption fee per dog to cover vetting including...',
#     'url': 'https://loveyloaves.typeform.com/to/dMbRFm'},
#    'social_media': {'facebook': 'http://www.facebook.com/loveyloavesinc',
#     'twitter': None,
#     'youtube': None,
#     'instagram': 'http://www.instagram.com/loveyloaves',
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/42214/1/?bust=1511943356&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/42214/1/?bust=1511943356&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/42214/1/?bust=1511943356&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/42214/1/?bust=1511943356'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/fl1171'},
#     'animals': {'href': '/v2/animals?organization=fl1171'}}},
#   {'id': 'TX886',
#    'name': 'Seagoville Animal Shelter',
#    'email': 'pets@seagoville.us',
#    'phone': '(972) 287-6838',
#    'address': {'address1': '1330 East Malloy Bridge Road',
#     'address2': None,
#     'city': 'Seagoville',
#     'state': 'TX',
#     'postcode': '75159',
#     'country': 'US'},
#    'hours': {'monday': '8-5',
#     'tuesday': '8-5',
#     'wednesday': '8-5',
#     'thursday': '8-5',
#     'friday': '8-5',
#     'saturday': '8-12',
#     'sunday': '8-12'},
#    'url': 'https://www.petfinder.com/member/us/tx/seagoville/seagoville-animal-shelter-tx886/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': 'http://www.seagoville.us',
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': 'https://www.facebook.com/seagovilleanimalshelter/',
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/38627/1/?bust=1511999672&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/38627/1/?bust=1511999672&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/38627/1/?bust=1511999672&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/38627/1/?bust=1511999672'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/tx886'},
#     'animals': {'href': '/v2/animals?organization=tx886'}}},
#   {'id': 'SC353',
#    'name': 'Furry Friends Rescue Center',
#    'email': 'melissaspets@aol.com',
#    'phone': '(803) 230-3648',
#    'address': {'address1': '2775 Ranger Rd',
#     'address2': None,
#     'city': 'Clover',
#     'state': 'SC',
#     'postcode': '29710',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/sc/clover/furry-friends-rescue-center-sc353/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': None,
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': 'https://www.facebook.com/FFRCinSC/?ref=bookmarks',
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/37274/1/?bust=1576610714&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/37274/1/?bust=1576610714&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/37274/1/?bust=1576610714&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/37274/1/?bust=1576610714'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/sc353'},
#     'animals': {'href': '/v2/animals?organization=sc353'}}},
#   {'id': 'AB78',
#    'name': 'Windy City Canine Rescue',
#    'email': 'info@windycityrescue.com',
#    'phone': '(403) 359-3139',
#    'address': {'address1': '880 Heritage Blvd W',
#     'address2': 'Box 325',
#     'city': 'Lethbridge',
#     'state': 'AB',
#     'postcode': 'T1K 7V5',
#     'country': 'CA'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/ca/ab/lethbridge/windy-city-canine-rescue-ab78/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': 'http://www.windycityrescue.com',
#    'mission_statement': 'The Windy City Canine Rescue is a group of volunteers based in Lethbridge, Alberta working to help older dogs in...',
#    'adoption': {'policy': 'If you are interested in adopting one of the dogs in our care, please complete the following steps:\r\n\r\n\r\nSit down...',
#     'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26051/2/?bust=1511939842&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26051/2/?bust=1511939842&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26051/2/?bust=1511939842&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26051/2/?bust=1511939842'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26051/1/?bust=1498786815&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26051/1/?bust=1498786815&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26051/1/?bust=1498786815&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/26051/1/?bust=1498786815'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/ab78'},
#     'animals': {'href': '/v2/animals?organization=ab78'}}},
#   {'id': 'MD360',
#    'name': 'TomCat Solutions',
#    'email': 'tom@tomcatsolutionsonline.org',
#    'phone': '410-822-1496  ',
#    'address': {'address1': '7865 Woodland Circle',
#     'address2': None,
#     'city': 'Easton',
#     'state': 'MD',
#     'postcode': '21601',
#     'country': 'US'},
#    'hours': {'monday': None,
#     'tuesday': None,
#     'wednesday': None,
#     'thursday': None,
#     'friday': None,
#     'saturday': None,
#     'sunday': None},
#    'url': 'https://www.petfinder.com/member/us/md/easton/tomcat-solutions-md360/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'website': None,
#    'mission_statement': 'We are a non-profit volunteer group dedicated to reducing the number - and improving the lives - of free roaming...',
#    'adoption': {'policy': None, 'url': None},
#    'social_media': {'facebook': None,
#     'twitter': None,
#     'youtube': None,
#     'instagram': None,
#     'pinterest': None},
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/31869/2/?bust=1512005243&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/31869/2/?bust=1512005243&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/31869/2/?bust=1512005243&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/31869/2/?bust=1512005243'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/31869/1/?bust=1501182346&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/31869/1/?bust=1501182346&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/31869/1/?bust=1501182346&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/organization-photos/31869/1/?bust=1501182346'}],
#    'distance': None,
#    '_links': {'self': {'href': '/v2/organizations/md360'},
#     'animals': {'href': '/v2/animals?organization=md360'}}},
#   ...]}

# %%
dog_breeds = pf.breeds('dog')
dog_breeds
# Out:
# {'breeds': {'dog': ['Affenpinscher',
#    'Afghan Hound',
#    'Airedale Terrier',
#    'Akbash',
#    'Akita',
#    'Alaskan Malamute',
#    'American Bulldog',
#    'American Bully',
#    'American Eskimo Dog',
#    'American Foxhound',
#    'American Hairless Terrier',
#    'American Staffordshire Terrier',
#    'American Water Spaniel',
#    'Anatolian Shepherd',
#    'Appenzell Mountain Dog',
#    'Aussiedoodle',
#    'Australian Cattle Dog / Blue Heeler',
#    'Australian Kelpie',
#    'Australian Shepherd',
#    'Australian Terrier',
#    'Basenji',
#    'Basset Hound',
#    'Beagle',
#    'Bearded Collie',
#    'Beauceron',
#    'Bedlington Terrier',
#    'Belgian Shepherd / Laekenois',
#    'Belgian Shepherd / Malinois',
#    'Belgian Shepherd / Sheepdog',
#    'Belgian Shepherd / Tervuren',
#    'Bernedoodle',
#    'Bernese Mountain Dog',
#    'Bichon Frise',
#    'Black and Tan Coonhound',
#    'Black Labrador Retriever',
#    'Black Mouth Cur',
#    'Black Russian Terrier',
#    'Bloodhound',
#    'Blue Lacy',
#    'Bluetick Coonhound',
#    'Boerboel',
#    'Bolognese',
#    'Border Collie',
#    'Border Terrier',
#    'Borzoi',
#    'Boston Terrier',
#    'Bouvier des Flandres',
#    'Boxer',
#    'Boykin Spaniel',
#    'Briard',
#    'Brittany Spaniel',
#    'Brussels Griffon',
#    'Bull Terrier',
#    'Bullmastiff',
#    'Cairn Terrier',
#    'Canaan Dog',
#    'Cane Corso',
#    'Cardigan Welsh Corgi',
#    'Carolina Dog',
#    'Catahoula Leopard Dog',
#    'Cattle Dog',
#    'Caucasian Sheepdog / Caucasian Ovtcharka',
#    'Cavachon',
#    'Cavalier King Charles Spaniel',
#    'Cavapoo',
#    'Chesapeake Bay Retriever',
#    'Chihuahua',
#    'Chinese Crested Dog',
#    'Chinese Foo Dog',
#    'Chinook',
#    'Chiweenie',
#    'Chocolate Labrador Retriever',
#    'Chow Chow',
#    "Cirneco dell'Etna",
#    'Clumber Spaniel',
#    'Cockapoo',
#    'Cocker Spaniel',
#    'Collie',
#    'Coonhound',
#    'Corgi',
#    'Coton de Tulear',
#    'Curly-Coated Retriever',
#    'Dachshund',
#    'Dalmatian',
#    'Dandie Dinmont Terrier',
#    'Doberman Pinscher',
#    'Dogo Argentino',
#    'Dogue de Bordeaux',
#    'Dutch Shepherd',
#    'English Bulldog',
#    'English Cocker Spaniel',
#    'English Coonhound',
#    'English Foxhound',
#    'English Pointer',
#    'English Setter',
#    'English Shepherd',
#    'English Springer Spaniel',
#    'English Toy Spaniel',
#    'Entlebucher',
#    'Eskimo Dog',
#    'Feist',
#    'Field Spaniel',
#    'Fila Brasileiro',
#    'Finnish Lapphund',
#    'Finnish Spitz',
#    'Flat-Coated Retriever',
#    'Fox Terrier',
#    'Foxhound',
#    'French Bulldog',
#    'Galgo Spanish Greyhound',
#    'German Pinscher',
#    'German Shepherd Dog',
#    'German Shorthaired Pointer',
#    'German Spitz',
#    'German Wirehaired Pointer',
#    'Giant Schnauzer',
#    'Glen of Imaal Terrier',
#    'Golden Retriever',
#    'Goldendoodle',
#    'Gordon Setter',
#    'Great Dane',
#    'Great Pyrenees',
#    'Greater Swiss Mountain Dog',
#    'Greyhound',
#    'Hamiltonstovare',
#    'Harrier',
#    'Havanese',
#    'Hound',
#    'Hovawart',
#    'Husky',
#    'Ibizan Hound',
#    'Icelandic Sheepdog',
#    'Illyrian Sheepdog',
#    'Irish Setter',
#    'Irish Terrier',
#    'Irish Water Spaniel',
#    'Irish Wolfhound',
#    'Italian Greyhound',
#    'Jack Russell Terrier',
#    'Japanese Chin',
#    'Jindo',
#    'Kai Dog',
#    'Karelian Bear Dog',
#    'Keeshond',
#    'Kerry Blue Terrier',
#    'Kishu',
#    'Klee Kai',
#    'Komondor',
#    'Kuvasz',
#    'Kyi Leo',
#    'Labradoodle',
#    'Labrador Retriever',
#    'Lakeland Terrier',
#    'Lancashire Heeler',
#    'Leonberger',
#    'Lhasa Apso',
#    'Lowchen',
#    'Lurcher',
#    'Maltese',
#    'Maltipoo',
#    'Manchester Terrier',
#    'Maremma Sheepdog',
#    'Mastiff',
#    'McNab',
#    'Miniature Bull Terrier',
#    'Miniature Dachshund',
#    'Miniature Pinscher',
#    'Miniature Poodle',
#    'Miniature Schnauzer',
#    'Mixed Breed',
#    'Morkie',
#    'Mountain Cur',
#    'Mountain Dog',
#    'Munsterlander',
#    'Neapolitan Mastiff',
#    'New Guinea Singing Dog',
#    'Newfoundland Dog',
#    'Norfolk Terrier',
#    'Norwegian Buhund',
#    'Norwegian Elkhound',
#    'Norwegian Lundehund',
#    'Norwich Terrier',
#    'Nova Scotia Duck Tolling Retriever',
#    'Old English Sheepdog',
#    'Otterhound',
#    'Papillon',
#    'Parson Russell Terrier',
#    'Patterdale Terrier / Fell Terrier',
#    'Pekingese',
#    'Pembroke Welsh Corgi',
#    'Peruvian Inca Orchid',
#    'Petit Basset Griffon Vendeen',
#    'Pharaoh Hound',
#    'Pit Bull Terrier',
#    'Plott Hound',
#    'Pointer',
#    'Polish Lowland Sheepdog',
#    'Pomeranian',
#    'Pomsky',
#    'Poodle',
#    'Portuguese Podengo',
#    'Portuguese Water Dog',
#    'Presa Canario',
#    'Pug',
#    'Puggle',
#    'Puli',
#    'Pumi',
#    'Pyrenean Shepherd',
#    'Rat Terrier',
#    'Redbone Coonhound',
#    'Retriever',
#    'Rhodesian Ridgeback',
#    'Rottweiler',
#    'Rough Collie',
#    'Saint Bernard',
#    'Saluki',
#    'Samoyed',
#    'Sarplaninac',
#    'Schipperke',
#    'Schnauzer',
#    'Schnoodle',
#    'Scottish Deerhound',
#    'Scottish Terrier',
#    'Sealyham Terrier',
#    'Setter',
#    'Shar-Pei',
#    'Sheep Dog',
#    'Sheepadoodle',
#    'Shepherd',
#    'Shetland Sheepdog / Sheltie',
#    'Shiba Inu',
#    'Shih poo',
#    'Shih Tzu',
#    'Shollie',
#    'Siberian Husky',
#    'Silky Terrier',
#    'Skye Terrier',
#    'Sloughi',
#    'Smooth Collie',
#    'Smooth Fox Terrier',
#    'South Russian Ovtcharka',
#    'Spaniel',
#    'Spanish Water Dog',
#    'Spinone Italiano',
#    'Spitz',
#    'Staffordshire Bull Terrier',
#    'Standard Poodle',
#    'Standard Schnauzer',
#    'Sussex Spaniel',
#    'Swedish Vallhund',
#    'Tennessee Treeing Brindle',
#    'Terrier',
#    'Thai Ridgeback',
#    'Tibetan Mastiff',
#    'Tibetan Spaniel',
#    'Tibetan Terrier',
#    'Tosa Inu',
#    'Toy Fox Terrier',
#    'Toy Manchester Terrier',
#    'Treeing Walker Coonhound',
#    'Vizsla',
#    'Weimaraner',
#    'Welsh Springer Spaniel',
#    'Welsh Terrier',
#    'West Highland White Terrier / Westie',
#    'Wheaten Terrier',
#    'Whippet',
#    'White German Shepherd',
#    'Wire Fox Terrier',
#    'Wirehaired Dachshund',
#    'Wirehaired Pointing Griffon',
#    'Wirehaired Terrier',
#    'Xoloitzcuintli / Mexican Hairless',
#    'Yellow Labrador Retriever',
#    'Yorkshire Terrier']}}

# %%
dogs = pf.animal_types('dog')
dogs
# Out:
# {'type': {'name': 'Dog',
#   'coats': ['Hairless', 'Short', 'Medium', 'Long', 'Wire', 'Curly'],
#   'colors': ['Apricot / Beige',
#    'Bicolor',
#    'Black',
#    'Brindle',
#    'Brown / Chocolate',
#    'Golden',
#    'Gray / Blue / Silver',
#    'Harlequin',
#    'Merle (Blue)',
#    'Merle (Red)',
#    'Red / Chestnut / Orange',
#    'Sable',
#    'Tricolor (Brown, Black, & White)',
#    'White / Cream',
#    'Yellow / Tan / Blond / Fawn'],
#   'genders': ['Male', 'Female'],
#   '_links': {'self': {'href': '/v2/types/dog'},
#    'breeds': {'href': '/v2/types/dog/breeds'}}}}

# %%
animals = pf.animals(results_per_page=50, pages=100, return_df = True)
animals
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-caa2ce8f459c> in <module>
# ----> 1 animals = pf.animals(results_per_page=50, pages=100, return_df = True)
#       2 animals
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/petpy/api.py in animals(self, animal_id, animal_type, breed, size, gender, age, color, coat, status, name, organization_id, location, distance, good_with_children, good_with_dogs, good_with_cats, before_date, after_date, sort, pages, results_per_page, return_df)
#     520                                 params=params)
#     521
# --> 522                 _check_api_rate_exceeded(r.json())
#     523
#     524                 animals = r.json()['animals']
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/petpy/api.py in _check_api_rate_exceeded(r, exit_loop)
#    1115                 return True
#    1116             else:
# -> 1117                 raise RuntimeError(r['title'])
#
# RuntimeError: Rate Limit Exceeded

# %%
animals["animals"][1]
# Out:
# {'id': 50347905,
#  'organization_id': 'WI524',
#  'url': 'https://www.petfinder.com/dog/thor-50347905/wi/racine/chrissys-k-9-kastle-wi524/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#  'type': 'Dog',
#  'species': 'Dog',
#  'breeds': {'primary': 'Boxer',
#   'secondary': 'Australian Cattle Dog / Blue Heeler',
#   'mixed': True,
#   'unknown': False},
#  'colors': {'primary': 'Red / Chestnut / Orange',
#   'secondary': 'White / Cream',
#   'tertiary': None},
#  'age': 'Baby',
#  'gender': 'Male',
#  'size': 'Medium',
#  'coat': 'Short',
#  'attributes': {'spayed_neutered': False,
#   'house_trained': False,
#   'declawed': None,
#   'special_needs': False,
#   'shots_current': True},
#  'environment': {'children': True, 'dogs': True, 'cats': None},
#  'tags': ['Loving',
#   'sweet',
#   'playful',
#   'crate trained',
#   'vaccinations up to date'],
#  'name': 'Thor',
#  'description': 'Hi, my name is Thor!  My mommy was saved from Texas and brought to Chrissy&#039;s K-9 Kastle in Racine, WI....',
#  'organization_animal_id': None,
#  'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347905/2/?bust=1611424249&width=100',
#    'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347905/2/?bust=1611424249&width=300',
#    'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347905/2/?bust=1611424249&width=600',
#    'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347905/2/?bust=1611424249'},
#   {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347905/1/?bust=1611424248&width=100',
#    'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347905/1/?bust=1611424248&width=300',
#    'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347905/1/?bust=1611424248&width=600',
#    'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347905/1/?bust=1611424248'}],
#  'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347905/2/?bust=1611424249&width=300',
#   'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347905/2/?bust=1611424249&width=450',
#   'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347905/2/?bust=1611424249&width=600',
#   'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347905/2/?bust=1611424249'},
#  'videos': [{'embed': '<iframe title="Video" src="https://www.facebook.com/video/embed?video_id=10215454698719957" frameborder="0" allowfullscreen></iframe>'}],
#  'status': 'adoptable',
#  'status_changed_at': '2021-01-23T17:58:59+0000',
#  'published_at': '2021-01-23T17:58:59+0000',
#  'distance': None,
#  'contact': {'email': 'shellyaholewinski@gmail.com',
#   'phone': '(262) 880-0567',
#   'address': {'address1': None,
#    'address2': None,
#    'city': 'Racine',
#    'state': 'WI',
#    'postcode': '53402',
#    'country': 'US'}},
#  '_links': {'self': {'href': '/v2/animals/50347905'},
#   'type': {'href': '/v2/types/dog'},
#   'organization': {'href': '/v2/organizations/wi524'}}}

# %%
animals["animals"][2]
# Out:
# {'id': 50347945,
#  'organization_id': 'MI181',
#  'url': 'https://www.petfinder.com/cat/mia-50347945/mi/muskegon/the-noah-project-mi181/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#  'type': 'Cat',
#  'species': 'Cat',
#  'breeds': {'primary': 'Domestic Short Hair',
#   'secondary': None,
#   'mixed': False,
#   'unknown': False},
#  'colors': {'primary': 'Calico', 'secondary': None, 'tertiary': None},
#  'age': 'Young',
#  'gender': 'Female',
#  'size': 'Small',
#  'coat': 'Short',
#  'attributes': {'spayed_neutered': False,
#   'house_trained': True,
#   'declawed': False,
#   'special_needs': False,
#   'shots_current': False},
#  'environment': {'children': None, 'dogs': None, 'cats': True},
#  'tags': [],
#  'name': 'Mia',
#  'description': 'Mia is a super sweet and friendly cat!  She came in with a litter and has done enough child rearing!...',
#  'organization_animal_id': '20F-101',
#  'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347945/1/?bust=1611424389&width=100',
#    'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347945/1/?bust=1611424389&width=300',
#    'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347945/1/?bust=1611424389&width=600',
#    'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347945/1/?bust=1611424389'},
#   {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347945/2/?bust=1611424395&width=100',
#    'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347945/2/?bust=1611424395&width=300',
#    'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347945/2/?bust=1611424395&width=600',
#    'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347945/2/?bust=1611424395'}],
#  'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347945/1/?bust=1611424389&width=300',
#   'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347945/1/?bust=1611424389&width=450',
#   'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347945/1/?bust=1611424389&width=600',
#   'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50347945/1/?bust=1611424389'},
#  'videos': [],
#  'status': 'adoptable',
#  'status_changed_at': '2021-01-23T17:57:27+0000',
#  'published_at': '2021-01-23T17:57:27+0000',
#  'distance': None,
#  'contact': {'email': 'info@noahprojectmuskegon.org',
#   'phone': '(231) 865-1264',
#   'address': {'address1': '5205 Airline Rd',
#    'address2': None,
#    'city': 'Muskegon',
#    'state': 'MI',
#    'postcode': '49443',
#    'country': 'US'}},
#  '_links': {'self': {'href': '/v2/animals/50347945'},
#   'type': {'href': '/v2/types/cat'},
#   'organization': {'href': '/v2/organizations/mi181'}}}

# %%
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# %%
db = client.rescue_angels_db

# %%
animals_collection = db.animals_collection

# %%
animals_collection = animals_collection.insert_one(animals["animals"][2])

# %%
for i in animals: 
    animal_dict = (animals["animals"][i])
    animals_collection.insert_one(animal_dict)
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-61bd2158aee5> in <module>
#       1 for i in animals:
#       2     #animals_collection.insert_one(animals["animals"][i])
# ----> 3     animal_dict = (animals["animals"][i])
#       4     animals_collection.insert_one(animal_dict)
#       5     time.sleep(1)
#
# TypeError: list indices must be integers or slices, not str

# %%
animal_dict = (animals["animals"][0])
print(animal_dict)
#type(animal_dict)
# Out:
# dict

# %%
animals_collection = db.animals_collection
animals_collection.insert_one(animals)
# Out:
# ---------------------------------------------------------------------------
# DocumentTooLarge                          Traceback (most recent call last)
# <ipython-input-28-7f256007571d> in <module>
#       1 animals_collection = db.animals_collection
# ----> 2 animals_collection.insert_one(animals)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     699                          write_concern=write_concern,
#     700                          bypass_doc_val=bypass_document_validation,
# --> 701                          session=session),
#     702             write_concern.acknowledged)
#     703
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     613             return self._insert_one(
#     614                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 615                 bypass_doc_val, session)
#     616
#     617         ids = []
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     601
#     602         self.__database.client._retryable_write(
# --> 603             acknowledged, _insert_command, session)
#     604
#     605         if not isinstance(doc, RawBSONDocument):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1496         """Internal retryable write helper."""
#    1497         with self._tmp_session(session) as s:
# -> 1498             return self._retry_with_session(retryable, func, s, None)
#    1499
#    1500     def _handle_getlasterror(self, address, error_msg):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1382         retryable = (retryable and self.retry_writes
#    1383                      and session and not session.in_transaction)
# -> 1384         return self._retry_internal(retryable, func, session, bulk)
#    1385
#    1386     def _retry_internal(self, retryable, func, session, bulk):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1414                             raise last_error
#    1415                         retryable = False
# -> 1416                     return func(session, sock_info, retryable)
#    1417             except ServerSelectionTimeoutError:
#    1418                 if is_retrying():
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/collection.py in _insert_command(session, sock_info, retryable_write)
#     596                 session=session,
#     597                 client=self.__database.client,
# --> 598                 retryable_write=retryable_write)
#     599
#     600             _check_write_command_response(result)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     697         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     698         except BaseException as error:
# --> 699             self._raise_connection_failure(error)
#     700
#     701     def send_message(self, message, max_doc_size):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     692                            unacknowledged=unacknowledged,
#     693                            user_fields=user_fields,
# --> 694                            exhaust_allowed=exhaust_allowed)
#     695         except OperationFailure:
#     696             raise
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/network.py in command(sock_info, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     134             and size > max_bson_size + message._COMMAND_OVERHEAD):
#     135         message._raise_document_too_large(
# --> 136             name, size, max_bson_size + message._COMMAND_OVERHEAD)
#     137
#     138     if publish:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymongo/message.py in _raise_document_too_large(operation, doc_size, max_size)
#    1086                                " - the connected server supports"
#    1087                                " BSON document sizes up to %d"
# -> 1088                                " bytes." % (doc_size, max_size))
#    1089     else:
#    1090         # There's nothing intelligent we can say
#
# DocumentTooLarge: BSON document too large (23206359 bytes) - the connected server supports BSON document sizes up to 16793598 bytes.

# %%
organization_collection = db.organization_collection

# %%
animals_collection = db.animals_collection
animals_collection.insert_one(animals)
