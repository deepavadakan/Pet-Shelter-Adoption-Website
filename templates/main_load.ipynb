# %%
import pandas as pd
import requests
import json
import pymongo
from config import API_key, API_secret

# %%
token_url = "https://api.petfinder.com/v2/oauth2/token"
credentials = {
    "grant_type" : "client_credentials",
    "client_id" : API_key,
    "client_secret" : API_secret
}
access_token_response = requests.post(token_url, data = credentials)
print(access_token_response.status_code)
# Out:
# 200

# %%
foo = access_token_response.json()
api_token = foo.get('access_token')

# %%
token_data = {
    "Authorization" :f"Bearer {api_token}"
}
token_data
# Out:
# {'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..LaZm8OrZkbhQ3a7_hYTwLJhyY_7K2KzrSOlNPZxjJZa-qoCBPIKKRJypL3WuF40z2zvr75yOH0O1ljXiBObkw3Ebuzz5uelmS7NaNVLJEHQAeNgspvGhb0iLaBFWuv83rjVot0KTC9QGQDxmKsu0EliJPm4f0lV13uSqctauMC3xNUg-2SABVFBWVfGQf7MyKA_xQQ87Z2Tf1vkoDhOSEHFj_DWmmQzi5rTd-mpAbAPQ-ckEmJ3t8X7qVt8xds9WHwmMT70xX9LxaYRkE9OLdbChS51BZk4m5kmjduo6DRgtb5CyVJYcxpXWI6FFa1Hl7Ylv4CziPtRsTN8AX6uzSA'}

# %%
query_url = "https://api.petfinder.com/v2/animals"
response = requests.get(query_url, headers = token_data)

response.json()
# Out:
# {'animals': [{'id': 50336095,
#    'organization_id': 'NC965',
#    'url': 'https://www.petfinder.com/dog/bubble-yum-50336095/nc/pittsboro/farm-friends-rescue-nc965/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Staffordshire Bull Terrier',
#     'secondary': 'Hound',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Black', 'secondary': 'Brindle', 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': None},
#    'tags': [],
#    'name': 'Bubble Yum',
#    'description': 'Bubble Yum is a big fluff ball of sweetness. From her fluffy little head, down to the tip of her...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336095/2/?bust=1611280224&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336095/2/?bust=1611280224&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336095/2/?bust=1611280224&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336095/2/?bust=1611280224'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336095/1/?bust=1611280207&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336095/1/?bust=1611280207&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336095/1/?bust=1611280207&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336095/1/?bust=1611280207'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336095/3/?bust=1611280383&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336095/3/?bust=1611280383&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336095/3/?bust=1611280383&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336095/3/?bust=1611280383'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336095/2/?bust=1611280224&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336095/2/?bust=1611280224&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336095/2/?bust=1611280224&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336095/2/?bust=1611280224'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2021-01-22T01:54:19+0000',
#    'published_at': '2021-01-22T01:54:19+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@farmfriendsrescue.org',
#     'phone': None,
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Pittsboro',
#      'state': 'NC',
#      'postcode': '27312',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/50336095'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/nc965'}}},
#   {'id': 50336106,
#    'organization_id': 'CT167',
#    'url': 'https://www.petfinder.com/cat/fettucine-50336106/ct/new-haven/the-greater-new-haven-cat-project-inc-ct167/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Black', 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': 'Medium',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Fettucine',
#    'description': 'Fettuccine is a 4 month old female kitten who was rescued in New Haven along with her sister, Linguine. With...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336106/2/?bust=1611280345&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336106/2/?bust=1611280345&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336106/2/?bust=1611280345&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336106/2/?bust=1611280345'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336106/1/?bust=1611280239&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336106/1/?bust=1611280239&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336106/1/?bust=1611280239&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336106/1/?bust=1611280239'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336106/2/?bust=1611280345&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336106/2/?bust=1611280345&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336106/2/?bust=1611280345&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336106/2/?bust=1611280345'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2021-01-22T01:52:34+0000',
#    'published_at': '2021-01-22T01:52:34+0000',
#    'distance': None,
#    'contact': {'email': 'gnhcp1@gnhcp.org',
#     'phone': '(203) 782-2287',
#     'address': {'address1': 'P.O. Box 1432',
#      'address2': None,
#      'city': 'New Haven',
#      'state': 'CT',
#      'postcode': '06505',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/50336106'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/ct167'}}},
#   {'id': 50336078,
#    'organization_id': 'NY1044',
#    'url': 'https://www.petfinder.com/dog/max-50336078/ny/seneca-falls/fetch-a-friend-rescue-ny1044/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pit Bull Terrier',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': '
},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2021-01-22T01:47:57+0000',
#    'published_at': '2021-01-22T01:47:57+0000',
#    'distance': None,
#    'contact': {'email': 'helpsedaliacats@gmail.com',
#     'phone': None,
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Sedalia',
#      'state': 'MO',
#      'postcode': '65301',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/50336073'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/mo725'}}},
#   {'id': 50336097,
#    'organization_id': 'FL668',
#    'url': 'https://www.petfinder.com/dog/palermo-50336097/fl/oviedo/save-a-life-pet-rescue-fl668/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Chihuahua',
#     'secondary': 'Dachshund',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Palermo',
#    'description': 'Please send Anna a text at 407.952.1037, along with a photo of this pet, to schedule and appointment in Oviedo....',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336097/1/?bust=1611280006&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336097/1/?bust=1611280006&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336097/1/?bust=1611280006&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336097/1/?bust=1611280006'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336097/1/?bust=1611280006&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336097/1/?bust=1611280006&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336097/1/?bust=1611280006&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336097/1/?bust=1611280006'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2021-01-22T01:47:04+0000',
#    'published_at': '2021-01-22T01:47:04+0000',
#    'distance': None,
#    'contact': {'email': 'Savealifepetres@aol.com',
#     'phone': '(407) 952-1037',
#     'address': {'address1': 'PO Box 623341',
#      'address2': None,
#      'city': 'Oviedo',
#      'state': 'FL',
#      'postcode': '32762',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/50336097'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl668'}}},
#   {'id': 50336101,
#    'organization_id': 'CA229',
#    'url': 'https://www.petfinder.com/cat/krampus-50336101/ca/fresno/valley-animal-center-ca229/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Medium Hair',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Krampus',
#    'description': 'Primary Color: Brown Tabby Age: 0yrs 0mths 10wks Animal has been Neutered',
#    'organization_animal_id': '23689',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2021-01-22T01:46:57+0000',
#    'published_at': '2021-01-22T01:46:57+0000',
#    'distance': None,
#    'contact': {'email': 'info@valleyanimal.org',
#     'phone': '(559) 233-8690',
#     'address': {'address1': '3934 N. Hayston Ave.',
#      'address2': None,
#      'city': 'Fresno',
#      'state': 'CA',
#      'postcode': '93728',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/50336101'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/ca229'}}},
#   {'id': 50336100,
#    'organization_id': 'CA229',
#    'url': 'https://www.petfinder.com/cat/helga-50336100/ca/fresno/valley-animal-center-ca229/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Helga',
#    'description': 'Primary Color: Calico Age: 0yrs 0mths 10wks Animal has been Spayed',
#    'organization_animal_id': '23719',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2021-01-22T01:46:56+0000',
#    'published_at': '2021-01-22T01:46:56+0000',
#    'distance': None,
#    'contact': {'email': 'info@valleyanimal.org',
#     'phone': '(559) 233-8690',
#     'address': {'address1': '3934 N. Hayston Ave.',
#      'address2': None,
#      'city': 'Fresno',
#      'state': 'CA',
#      'postcode': '93728',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/50336100'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/ca229'}}},
#   {'id': 50336011,
#    'organization_id': 'OH1256',
#    'url': 'https://www.petfinder.com/dog/flash-50336011/oh/wilmington/paws-humane-society-inc-oh1256/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Boxer',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': False},
#    'tags': [],
#    'name': 'Flash',
#    'description': 'Flash is very sweet &amp; playful.  He has lots of energy.  Flash lives up to his name; he can run...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336011/2/?bust=1611279232&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336011/2/?bust=1611279232&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336011/2/?bust=1611279232&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336011/2/?bust=1611279232'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336011/1/?bust=1611279466&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336011/1/?bust=1611279466&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336011/1/?bust=1611279466&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336011/1/?bust=1611279466'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336011/2/crop/?bust=1611279232&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336011/2/crop/?bust=1611279232&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336011/2/crop/?bust=1611279232&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336011/2/crop/?bust=1611279232'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2021-01-22T01:45:31+0000',
#    'published_at': '2021-01-22T01:45:31+0000',
#    'distance': None,
#    'contact': {'email': 'PAWShumanesocietyinc@gmail.com',
#     'phone': '(937) 768-4203',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Wilmington',
#      'state': 'OH',
#      'postcode': '45177',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/50336011'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/oh1256'}}},
#   {'id': 50336093,
#    'organization_id': 'MI192',
#    'url': 'https://www.petfinder.com/cat/bailey-50336093/mi/west-olive/harbor-humane-society-mi192/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Calico', 'secondary': None, 'tertiary': None},
#    'age': 'Senior',
#    'gender': 'Female',
#    'size': 'Extra Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Bailey',
#    'description': None,
#    'organization_animal_id': 'HHMI-A-41790',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2021-01-22T01:45:18+0000',
#    'published_at': '2021-01-22T01:45:18+0000',
#    'distance': None,
#    'contact': {'email': 'office@harborhumane.org',
#     'phone': '(616) 399-2119',
#     'address': {'address1': '14345 Bagley St',
#      'address2': None,
#      'city': 'West Olive',
#      'state': 'MI',
#      'postcode': '49460',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/50336093'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/mi192'}}},
#   {'id': 50336089,
#    'organization_id': 'MD448',
#    'url': 'https://www.petfinder.com/cat/0120-81-sophie-50336089/md/abingdon/best-friends-in-harford-county-inc-md448/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Orange / Red', 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': '0120-81 Sophie',
#    'description': None,
#    'organization_animal_id': 'BFHC-A-1900',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2021-01-22T01:45:12+0000',
#    'published_at': '2021-01-22T01:45:12+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@bestfriendsinharfordcounty.org',
#     'phone': '(443) 390-6676',
#     'address': {'address1': 'P.O. Box 258',
#      'address2': None,
#      'city': 'Abingdon',
#      'state': 'MD',
#      'postcode': '21009',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/50336089'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/md448'}}},
#   {'id': 50336090,
#    'organization_id': 'MD448',
#    'url': 'https://www.petfinder.com/cat/0120-80-mittens-50336090/md/abingdon/best-friends-in-harford-county-inc-md448/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Black', 'secondary': 'White', 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': '0120-80 Mittens',
#    'description': None,
#    'organization_animal_id': 'BFHC-A-1963',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2021-01-22T01:45:12+0000',
#    'published_at': '2021-01-22T01:45:12+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@bestfriendsinharfordcounty.org',
#     'phone': '(443) 390-6676',
#     'address': {'address1': 'P.O. Box 258',
#      'address2': None,
#      'city': 'Abingdon',
#      'state': 'MD',
#      'postcode': '21009',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/50336090'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/md448'}}},
#   {'id': 50336091,
#    'organization_id': 'MD448',
#    'url': 'https://www.petfinder.com/cat/0121-78-marianne-50336091/md/abingdon/best-friends-in-harford-county-inc-md448/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Calico', 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': '0121-78 Marianne',
#    'description': None,
#    'organization_animal_id': 'BFHC-A-1896',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2021-01-22T01:45:12+0000',
#    'published_at': '2021-01-22T01:45:12+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@bestfriendsinharfordcounty.org',
#     'phone': '(443) 390-6676',
#     'address': {'address1': 'P.O. Box 258',
#      'address2': None,
#      'city': 'Abingdon',
#      'state': 'MD',
#      'postcode': '21009',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/50336091'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/md448'}}},
#   {'id': 50336092,
#    'organization_id': 'MD448',
#    'url': 'https://www.petfinder.com/cat/0121-79-ginger-50336092/md/abingdon/best-friends-in-harford-county-inc-md448/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Calico', 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': '0121-79 Ginger',
#    'description': None,
#    'organization_animal_id': 'BFHC-A-1895',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2021-01-22T01:45:12+0000',
#    'published_at': '2021-01-22T01:45:12+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@bestfriendsinharfordcounty.org',
#     'phone': '(443) 390-6676',
#     'address': {'address1': 'P.O. Box 258',
#      'address2': None,
#      'city': 'Abingdon',
#      'state': 'MD',
#      'postcode': '21009',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/50336092'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/md448'}}},
#   {'id': 50336080,
#    'organization_id': 'IL959',
#    'url': 'https://www.petfinder.com/dog/aj-50336080/il/rosemont/border-tails-rescue-il959/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': None},
#    'tags': [],
#    'name': 'AJ',
#    'description': 'AJ is a handsome guy with one brown &amp; one blue eye. He is a super sweet and spunky guy...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336080/1/?bust=1611279831&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336080/1/?bust=1611279831&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336080/1/?bust=1611279831&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336080/1/?bust=1611279831'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336080/1/?bust=1611279831&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336080/1/?bust=1611279831&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336080/1/?bust=1611279831&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336080/1/?bust=1611279831'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2021-01-22T01:44:44+0000',
#    'published_at': '2021-01-22T01:44:44+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@bordertailsrescue.org',
#     'phone': '(224) 420-1900',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Rosemont',
#      'state': 'IL',
#      'postcode': '60018',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/50336080'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/il959'}}},
#   {'id': 50336075,
#    'organization_id': 'FL318',
#    'url': 'https://www.petfinder.com/dog/patch-50336075/fl/fernandina-beach/nassau-humane-society-fl318/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Mixed Breed',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'PATCH',
#    'description': 'Cute puppy alert! Patch is not quite two months old, with a tan and white coat and the most adorable...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336075/1/?bust=1611279827&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336075/1/?bust=1611279827&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336075/1/?bust=1611279827&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336075/1/?bust=1611279827'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336075/1/?bust=1611279827&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336075/1/?bust=1611279827&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336075/1/?bust=1611279827&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336075/1/?bust=1611279827'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2021-01-22T01:44:42+0000',
#    'published_at': '2021-01-22T01:44:42+0000',
#    'distance': None,
#    'contact': {'email': 'info@nassauhumane.org',
#     'phone': '(904) 321-1647',
#     'address': {'address1': '639 Airport Road',
#      'address2': None,
#      'city': 'Fernandina Beach',
#      'state': 'FL',
#      'postcode': '32034',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/50336075'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl318'}}},
#   {'id': 50336081,
#    'organization_id': 'FL668',
#    'url': 'https://www.petfinder.com/dog/sima-50336081/fl/oviedo/save-a-life-pet-rescue-fl668/?referrer_id=6da4e412-02a8-47a5-aa79-d318e2281079',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Chihuahua',
#     'secondary': 'Dachshund',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Sima',
#    'description': 'Please send Anna a text at 407.952.1037, along with a photo of this pet, to schedule and appointment in Oviedo....',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336081/1/?bust=1611279830&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336081/1/?bust=1611279830&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336081/1/?bust=1611279830&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336081/1/?bust=1611279830'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336081/1/?bust=1611279830&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336081/1/?bust=1611279830&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336081/1/?bust=1611279830&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/50336081/1/?bust=1611279830'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2021-01-22T01:44:09+0000',
#    'published_at': '2021-01-22T01:44:09+0000',
#    'distance': None,
#    'contact': {'email': 'Savealifepetres@aol.com',
#     'phone': '(407) 952-1037',
#     'address': {'address1': 'PO Box 623341',
#      'address2': None,
#      'city': 'Oviedo',
#      'state': 'FL',
#      'postcode': '32762',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/50336081'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl668'}}}],
#  'pagination': {'count_per_page': 20,
#   'total_count': 132926,
#   'current_page': 1,
#   'total_pages': 6647,
#   '_links': {'next': {'href': '/v2/animals?page=2'}}}}

# %%
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# %%
db = client.pet_rescue_test_db
test_collection = db.test_collection

# %%
test_collection.insert_many(response)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-f0ddd1996ea2> in <module>
# ----> 1 test_collection.insert_many(response)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     758         write_concern = self._write_concern_for(session)
#     759         blk = _Bulk(self, ordered, bypass_document_validation)
# --> 760         blk.ops = [doc for doc in gen()]
#     761         blk.execute(write_concern, session=session)
#     762         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\collection.py in <listcomp>(.0)
#     758         write_concern = self._write_concern_for(session)
#     759         blk = _Bulk(self, ordered, bypass_document_validation)
# --> 760         blk.ops = [doc for doc in gen()]
#     761         blk.execute(write_concern, session=session)
#     762         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\collection.py in gen()
#     749             """A generator that validates documents and handles _ids."""
#     750             for document in documents:
# --> 751                 common.validate_is_document_type("document", document)
#     752                 if not isinstance(document, RawBSONDocument):
#     753                     if "_id" not in document:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\common.py in validate_is_document_type(option, value)
#     503                         "bson.raw_bson.RawBSONDocument, or "
#     504                         "a type that inherits from "
# --> 505                         "collections.MutableMapping" % (option,))
#     506
#     507
#
# TypeError: document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
